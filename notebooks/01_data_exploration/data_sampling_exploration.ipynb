# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load your dataset (adjust the path to where your file is located)
df = pd.read_csv('../../data/Tdata.csv',parse_dates=["Date"],index_col="Date")

# %%
df
# Out:
#             User Count Average  Average User Throughput DL  \
# Date
# 2023-04-01            23286.87                    5.633309
# 2023-08-01            23677.76                    7.364028
# 2022-12-01            20755.21                    5.066298
# 2023-02-01            21880.87                    5.382316
# 2023-01-01            20811.78                    5.389850
# ...                        ...                         ...
# 2023-03-09            23350.58                    5.057684
# 2023-05-09            22459.26                    5.047216
# 2022-11-09            17475.45                    3.133588
# 2022-10-09            16437.81                    3.316680
# 2022-09-09            15824.22                    3.410580
#
#             Average User Throughput UL       CSSR  DL_256QAM_PROPORTION  \
# Date
# 2023-04-01                    0.679596  98.804118              0.988493
# 2023-08-01                    0.471457  95.325628              0.820870
# ...

# %%
df.columns
# Out:
# Index(['User Count Average', 'Average User Throughput DL',
#        'Average User Throughput UL', 'CSSR', 'DL_256QAM_PROPORTION',
#        'DL_LATENCY', 'DL_PACK_LOSS_RATE', 'DL_QPSK_PROPORTION',
#        'Data Volume DL', 'User Count Maximum', 'S1_SIG_SUCC', 'TOTAL_DOWNTIME',
#        'Traffic', 'UL_QPSK_PROPORTION', 'UL_TRAFFIC_MB'],
#       dtype='object')

# %%
df.CSSR.resample('M').mean()
# Out:
# Date
# 2022-09-30    98.703963
# 2022-10-31    98.646116
# 2022-11-30    97.743067
# 2022-12-31    98.108688
# 2023-01-31    98.359243
# 2023-02-28    98.281485
# 2023-03-31    98.719604
# 2023-04-30    98.845475
# 2023-05-31    99.004199
# 2023-06-30    98.164591
# 2023-07-31    98.082459
# 2023-08-31    98.657499
# 2023-09-30    99.655806
# Freq: M, Name: CSSR, dtype: float64

# %%
df.CSSR.resample('S').mean().plot()

# %%
# Calculate the correlation matrix
corr_matrix = data.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12128\1809578628.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()

# %%
# Calculate the correlation matrix
corr_matrix = data.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')

# Save the image
plt.savefig('correlation_matrix.png')  # Adjust the filename as needed

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12128\1361533373.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()

# %%
data
# Out:
#              STARTTIME_DATE        ERBS     Site EUTRANCELLFDD   Area  \
# 0       2022-09-01 00:00:00  CXUKH48_01  CXUKH48     CXUKH48LA  CXUKH
# 1       2022-09-01 00:00:00  CXUKH62_02  CXUKH62     CXUKH62LC  CXUKH
# 2       2022-09-01 00:00:00    CXUKH28L  CXUKH28     CXUKH28LF  CXUKH
# 3       2022-09-01 00:00:00  CXUKH30_01  CXUKH30     CXUKH30LA  CXUKH
# 4       2022-09-01 00:00:00    CXUKH39L  CXUKH39     CXUKH39LB  CXUKH
# ...                     ...         ...      ...           ...    ...
# 360298  2023-09-01 00:00:00     BMKSB35  BMKSB35     BMKSB35LA  BMKSB
# 360299  2023-09-01 00:00:00  BMKSB28B02  BMKSB28   BMKSB28L21B  BMKSB
# 360300  2023-09-01 00:00:00  BMKSB28B02  BMKSB28   BMKSB28L21C  BMKSB
# 360301  2023-09-01 00:00:00    BMKSB20L  BMKSB20   BMKSB20L21A  BMKSB
# 360302  2023-09-01 00:00:00     BMKSB38  BMKSB38     BMKSB38LA  BMKSB
#
#         AVG_NO_USER  AVG_USR_THRPUT_DL  AVG_USR_THRPUT_UL   CSSR  \
# ...

# %%
# Create the pivot table
pivot_table = data.pivot_table(
    index=['STARTTIME_DATE'],    # Rows
    columns=['EUTRANCELLFDD'], # Columns
    values=['AVG_NO_USER',], # Values
    aggfunc='max',              # Aggregate function (sum in this case)
    fill_value=0                 # Fill missing values with 0
)

# Display the pivot table
print(pivot_table)
# Out:
#                     AVG_NO_USER                                       \
# EUTRANCELLFDD       BMKSB02L21A BMKSB02L21B BMKSB02L21C BMKSB02L26A1
# STARTTIME_DATE
# 2022-09-01 00:00:00        3.15        2.23        8.48         0.00
# 2022-09-02 00:00:00        3.05        2.40        7.94         0.00
# 2022-09-03 00:00:00        2.84        2.69        7.33         0.00
# 2022-09-04 00:00:00        2.88        2.65        8.51         0.00
# 2022-09-05 00:00:00        2.82        2.61        9.07         0.00
# ...                         ...         ...         ...          ...
# 2023-08-28 00:00:00       17.78       24.13       24.64        17.37
# 2023-08-29 00:00:00       19.08       27.17       22.37        19.24
# 2023-08-30 00:00:00       21.10       31.16       21.66        22.71
# 2023-08-31 00:00:00       19.00       20.71       22.98        20.90
# 2023-09-01 00:00:00       23.00       26.39       19.64        20.75
#
# ...

# %%
pivot_table
# Out:
#                     AVG_NO_USER                                       \
# EUTRANCELLFDD       BMKSB02L21A BMKSB02L21B BMKSB02L21C BMKSB02L26A1
# STARTTIME_DATE
# 2022-09-01 00:00:00        3.15        2.23        8.48         0.00
# 2022-09-02 00:00:00        3.05        2.40        7.94         0.00
# 2022-09-03 00:00:00        2.84        2.69        7.33         0.00
# 2022-09-04 00:00:00        2.88        2.65        8.51         0.00
# 2022-09-05 00:00:00        2.82        2.61        9.07         0.00
# ...                         ...         ...         ...          ...
# 2023-08-28 00:00:00       17.78       24.13       24.64        17.37
# 2023-08-29 00:00:00       19.08       27.17       22.37        19.24
# 2023-08-30 00:00:00       21.10       31.16       21.66        22.71
# 2023-08-31 00:00:00       19.00       20.71       22.98        20.90
# 2023-09-01 00:00:00       23.00       26.39       19.64        20.75
#
# ...

# %%
variances = data.var()  # Calculate variance for each column
most_random_column = variances.idxmax()  # Get the column name with highest variance
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15644\755234506.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   variances = data.var()  # Calculate variance for each column

# %%
cv = data.std() / data.mean()  # Calculate CV for each column
most_random_column = cv.idxmax()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15644\3548471412.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cv = data.std() / data.mean()  # Calculate CV for each column
# C:\Users\HP\AppData\Local\Temp\ipykernel_15644\3548471412.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cv = data.std() / data.mean()  # Calculate CV for each column

# %%
cv
# Out:
# AVG_NO_USER             1.034029
# AVG_USR_THRPUT_DL       0.955888
# AVG_USR_THRPUT_UL       1.040465
# CSSR                    0.071422
# DL_256QAM_PROPORTION    1.384129
# DL_LATENCY              1.041727
# DL_PACK_LOSS_RATE       4.382458
# DL_QPSK_PROPORTION      0.319165
# DL_TRAFFIC_MB           0.676919
# MAX_NO_USER             0.860607
# S1_SIG_SUCC             1.084707
# TOTAL_DOWNTIME          8.878113
# TOTAL_TRAFFIC           0.690207
# UL_QPSK_PROPORTION      0.394536
# UL_TRAFFIC_MB           0.906721
# dtype: float64

# %%
variances
# Out:
# AVG_NO_USER             2.750470e+03
# AVG_USR_THRPUT_DL       2.966464e+01
# AVG_USR_THRPUT_UL       3.363277e-01
# CSSR                    4.991149e+01
# DL_256QAM_PROPORTION    1.520116e+00
# DL_LATENCY              4.876998e+01
# DL_PACK_LOSS_RATE       1.468621e-01
# DL_QPSK_PROPORTION      1.500241e+02
# DL_TRAFFIC_MB           6.029368e+09
# MAX_NO_USER             9.484660e+03
# S1_SIG_SUCC             2.814692e+10
# TOTAL_DOWNTIME          4.539051e+07
# TOTAL_TRAFFIC           7.951572e+09
# UL_QPSK_PROPORTION      3.178636e+02
# UL_TRAFFIC_MB           1.725200e+08
# dtype: float64

# %%
# Load your dataset (adjust the path to where your file is located)
data = pd.read_csv('../../data/Area2.csv')

# %%
data
# Out:
#                     Date  AVG_NO_USER  AVG_USR_THRPUT_DL  DL_TRAFFIC_MB
# 0    2022-09-01 00:00:00      9954.47            1086.49    25704066.05
# 1    2022-09-02 00:00:00     10985.26            1049.03    28559806.80
# 2    2022-09-03 00:00:00     10167.22            1141.17    26620210.70
# 3    2022-09-04 00:00:00     10006.20            1113.27    25847928.44
# 4    2022-09-05 00:00:00      9653.36            1199.39    25578331.71
# ..                   ...          ...                ...            ...
# 361  2023-08-28 00:00:00     12920.11            3292.58    38016179.98
# 362  2023-08-29 00:00:00     13176.04            3331.04    38207800.05
# 363  2023-08-30 00:00:00     12911.03            3513.51    38603784.04
# 364  2023-08-31 00:00:00     13417.00            3533.71    38814914.71
# 365  2023-09-01 00:00:00     13802.56            3644.71    41004140.68
#
# [366 rows x 4 columns]
