# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
from sklearn.preprocessing import MaxAbsScaler
from sklearn.svm import SVR
from tensorflow.keras.layers import GRU, LSTM, Dense, Dropout

# %%
# Load your dataset (adjust the path to where your file is located)
data = pd.read_csv('../../data/Tdata.csv')

# %%
data
# Out:
#           Date   Avg_Usr  Avg_Usr_TP_DL  Avg_Usr_TP_UL       CSSR  \
# 0     1-Sep-22  16209.61       3.446027       0.564643  98.698393
# 1     2-Sep-22  16003.68       3.250536       0.582187  98.690223
# 2     3-Sep-22  16058.39       3.597009       0.609911  98.715045
# 3     4-Sep-22  16390.15       3.726696       0.561250  98.599777
# 4     5-Sep-22  16051.58       3.726473       0.537813  98.653527
# ..         ...       ...            ...            ...        ...
# 361  28-Aug-23  23298.68       7.064972       0.477116  99.415142
# 362  29-Aug-23  24511.92       6.966452       0.490361  99.463776
# 363  30-Aug-23  24467.48       6.898596       0.493188  99.626964
# 364  31-Aug-23  23803.97       7.090190       0.510664  99.661120
# 365   1-Sep-23  23264.06       7.206679       0.558558  99.655806
#
#      DL_256QAM_PROPORTION  DL_LATENCY  DL_PACK_LOSS_RATE  DL_QPSK_PROPORTION  \
# 0                0.745357   11.741116           0.101875           36.163527
# 1                0.700536   11.614241           0.115580           35.475402
# 2                0.739732   11.503259           0.096250           35.623393
# 3                0.746696   11.807366           0.110536           35.997411
# 4                0.751071   11.534911           0.111250           35.609866
# ..                    ...         ...                ...                 ...
# 361              0.773226    7.505920           0.078786           38.537059
# 362              0.727324    7.704269           0.097002           38.737799
# 363              0.754516    7.891157           0.096129           38.392467
# 364              0.809222    7.563378           0.088520           38.284099
# 365              0.750019    7.531954           0.088008           38.537457
#
#      DL_TRAFFIC_MB  Max_Usr  S1_SIG_SUCC  TOTAL_DOWNTIME      Traffic  \
# 0      28748026.10    32848  251968.1429      393.651786  32890183.17
# 1      29619777.66    32313  243918.5625      389.156250  34033315.47
# 2      29102851.45    32565  246798.6027      388.062500  33383868.74
# 3      28466880.25    33303  257327.6563      387.245536  32606986.82
# 4      28558733.04    32314  256012.4866      390.343750  32652591.96
# ..             ...      ...          ...             ...          ...
# 361    56768939.70    58629  127670.3321     1092.662239  63974723.71
# 362    57456743.34    54688  129612.0247     1074.193548  64944563.74
# 363    58389814.53    56111  133872.1556      362.741936  65854384.38
# 364    59759544.72    51682  134106.0171        0.000000  67421649.20
# 365    59760454.24    51146  127557.1765       11.464896  67634282.38
#
#      UL_QPSK_PROPORTION  UL_TRAFFIC_MB
# 0             37.050402     4142157.11
# 1             38.724911     4413537.60
# 2             36.708884     4281017.27
# 3             36.628527     4140106.66
# 4             37.344955     4093859.29
# ..                  ...            ...
# 361           42.272201     7205784.11
# 362           40.884345     7487820.29
# 363           40.078159     7464569.80
# 364           39.138444     7662104.58
# 365           39.083150     7873828.23
#
# [366 rows x 16 columns]

# %%
# Function to create dataset matrix for LSTM
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), :])
        Y.append(dataset[i + look_back, :])
    return np.array(X), np.array(Y)

# Function to build and train LSTM model with given hyperparameters
def train_lstm_model(X_train, y_train, X_test, y_test, units, dropout_rate, batch_size, epochs, optimizer):
    model = Sequential()
    model.add(LSTM(units, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]), stateful=False))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(units // 2, return_sequences=False))
    model.add(Dense(1))

    model.compile(optimizer=optimizer, loss='mean_squared_error')

    early_stop = EarlyStopping(monitor='val_loss', patience=10)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=1, callbacks=[early_stop, reduce_lr])

    test_predict = model.predict(X_test)
    return model, test_predict, history

# Preparing data for 'Avg_Usr'
feature = 'Avg_Usr'

# Normalize the 'Avg_Usr' data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[[feature]])

# Split the data into training and test sets (80% train, 20% test)
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[:train_size], scaled_data[train_size:]

# Create dataset for LSTM (look_back=3)  # Adjust window size
look_back = 3
X_train, y_train = create_dataset(train, look_back=look_back)
X_test, y_test = create_dataset(test, look_back=look_back)

# Reshape input data to 3D (samples, timesteps, features) for LSTM input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Train the best model directly with known parameters
units = 50
dropout_rate = 0.4
batch_size = 64
epochs = 50
optimizer = 'rmsprop'

# Train model
model, test_predict, history = train_lstm_model(X_train, y_train, X_test, y_test, units, dropout_rate, batch_size, epochs, optimizer)

# Calculate MSE with normalized data
mse = mean_squared_error(y_test, test_predict)
print(f'MSE (normalized): {mse}')

# Invert the scaling (to return to original values)
#test_predict = scaler.inverse_transform(test_predict)
#y_test = scaler.inverse_transform(y_test)

# Shift the predictions back by window size (look_back) to align with actual values
test_predict_shifted = np.empty_like(y_test)
test_predict_shifted[:] = np.nan
#test_predict_shifted[look_back:] = test_predict[:-look_back]
test_predict_shifted[:-look_back] = test_predict[look_back:]

# Plot the best model's predictions with actual values
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual', color='blue')
plt.plot(test_predict_shifted, label='Predicted', color='red')
plt.title(f'Actual vs Predicted for {feature}')
plt.xlabel('Time')
plt.ylabel(f'{feature}')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 5/5 [==============================] - 6s 257ms/step - loss: 0.2169 - val_loss: 0.2102 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1390 - val_loss: 0.1216 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0813 - val_loss: 0.0673 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0498 - val_loss: 0.0269 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.0111 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0083 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0217 - val_loss: 0.0047 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0196 - val_loss: 0.0072 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0173 - val_loss: 0.0061 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.0026 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0125 - val_loss: 0.0036 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0108 - val_loss: 0.0022 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0093 - val_loss: 0.0029 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0046 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.0054 - lr: 0.0010
# Epoch 16/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0030 - lr: 0.0010
# Epoch 17/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0033 - lr: 0.0010
# Epoch 18/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0034 - lr: 0.0010
# Epoch 19/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0052 - val_loss: 0.0031 - lr: 0.0010
# Epoch 20/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0026 - lr: 0.0010
# Epoch 21/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0074 - lr: 0.0010
# Epoch 22/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0063 - lr: 0.0010
# 3/3 [==============================] - 1s 4ms/step
# MSE (normalized): 0.00846454925502464

# %%
# Calculate MSE with normalized data
mse = mean_squared_error(y_test, test_predict)
print(f'MSE (normalized): {mse}')
# Out:
# MSE (normalized): 0.00846454925502464

# %%
# Print actual and predicted values side by side for comparison
print("Actual values vs Predicted values:")
for actual, predicted in zip(y_test[look_back:], test_predict):
    print(f"Actual: {actual[0]}, Predicted: {predicted[0]}")
# Out:
# Actual values vs Predicted values:
# Actual: 0.6684488029242117, Predicted: 0.6609667539596558
# Actual: 0.6335620600360854, Predicted: 0.6646897792816162
# Actual: 0.676685768774131, Predicted: 0.6728672981262207
# Actual: 0.8726406715964439, Predicted: 0.6770458221435547
# Actual: 0.8204498499565296, Predicted: 0.6983339786529541
# Actual: 0.7820396563490357, Predicted: 0.7113858461380005
# Actual: 0.8317577989884923, Predicted: 0.7143852114677429
# Actual: 0.7942132767437298, Predicted: 0.7442240715026855
# Actual: 0.7839729267357831, Predicted: 0.820755660533905
# Actual: 0.7734932550552029, Predicted: 0.8920614719390869
# Actual: 0.7728454038085801, Predicted: 0.8626904487609863
# Actual: 0.7071057970066095, Predicted: 0.8541181087493896
# Actual: 0.7231487627256494, Predicted: 0.8642615079879761
# Actual: 0.7541446587329039, Predicted: 0.8411037921905518
# Actual: 0.7315717637820303, Predicted: 0.8326374888420105
# Actual: 0.7261113032747808, Predicted: 0.8165087103843689
# Actual: 0.7663986762519985, Predicted: 0.7973697781562805
# Actual: 0.8298787499182008, Predicted: 0.7757468819618225
# Actual: 0.5282969832381346, Predicted: 0.7899799942970276
# Actual: 0.6435556095691277, Predicted: 0.796769917011261
# Actual: 0.688642503903, Predicted: 0.7906702756881714
# Actual: 0.7359823874206546, Predicted: 0.8116681575775146
# Actual: 0.7284811487440286, Predicted: 0.8020606637001038
# Actual: 0.7856902467069897, Predicted: 0.7532029747962952
# Actual: 0.7904907029139285, Predicted: 0.6507622003555298
# Actual: 0.7357505445502905, Predicted: 0.7302990555763245
# Actual: 0.8339593714066695, Predicted: 0.7666901350021362
# Actual: 0.8213987229945126, Predicted: 0.7967847585678101
# Actual: 0.925661640288308, Predicted: 0.8126196265220642
# Actual: 0.9094906000803973, Predicted: 0.832890510559082
# Actual: 0.7602763417438698, Predicted: 0.8335646986961365
# Actual: 0.870739186119343, Predicted: 0.8369296193122864
# Actual: 0.8060877450476309, Predicted: 0.8971437811851501
# Actual: 0.7737998859482653, Predicted: 0.9219021201133728
# Actual: 0.8529975974347712, Predicted: 0.9423309564590454
# Actual: 0.7690508465069321, Predicted: 0.9047890901565552
# Actual: 0.7341884097261824, Predicted: 0.8581781387329102
# Actual: 0.7450681973281981, Predicted: 0.8851813077926636
# Actual: 0.6786414755676882, Predicted: 0.8565709590911865
# Actual: 0.6338855182342549, Predicted: 0.8528976440429688
# Actual: 0.7391720965887316, Predicted: 0.85819411277771
# Actual: 0.5852377791696664, Predicted: 0.8080084919929504
# Actual: 0.47157307257242764, Predicted: 0.7836010456085205
# Actual: 0.754544774654339, Predicted: 0.7596387267112732
# Actual: 0.582611784722677, Predicted: 0.7299471497535706
# Actual: 0.6894427357458701, Predicted: 0.7170357704162598
# Actual: 0.7718077199936428, Predicted: 0.6986744403839111
# Actual: 0.7590816030812668, Predicted: 0.6326861381530762
# Actual: 0.7914526638558836, Predicted: 0.6419079303741455
# Actual: 0.8306845908627736, Predicted: 0.7419062852859497
# Actual: 0.8229917078779834, Predicted: 0.7066634893417358
# Actual: 0.8378240424795971, Predicted: 0.7839115858078003
# Actual: 0.8579074311249055, Predicted: 0.8251180052757263
# Actual: 0.7992689470781253, Predicted: 0.8359337449073792
# Actual: 0.8429040189213697, Predicted: 0.8630161285400391
# Actual: 0.8464480363469793, Predicted: 0.881826639175415
# Actual: 0.7884751657022129, Predicted: 0.886175811290741
# Actual: 0.7965943404163824, Predicted: 0.8902169466018677
# Actual: 0.7872084435677627, Predicted: 0.8880839347839355
# Actual: 0.8272779964288719, Predicted: 0.8745500445365906
# Actual: 0.7187708588469559, Predicted: 0.8872101902961731
# Actual: 0.6922379380942143, Predicted: 0.8715443015098572
# Actual: 0.6445942282343484, Predicted: 0.8446796536445618
# Actual: 0.698750105170657, Predicted: 0.8521255254745483
# Actual: 0.8121698809935589, Predicted: 0.8427813649177551
# Actual: 0.8080154063326761, Predicted: 0.8225024938583374
# Actual: 0.7459871551571018, Predicted: 0.7530467510223389
# Actual: 0.6955136534883941, Predicted: 0.7333923578262329

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
# Function to create dataset matrix for GRU
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), :])
        Y.append(dataset[i + look_back, :])
    return np.array(X), np.array(Y)

# Function to build and train GRU model with given hyperparameters
def train_gru_model(X_train, y_train, X_test, y_test, units, dropout_rate, batch_size, epochs, optimizer):
    model = Sequential()
    model.add(GRU(units, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(dropout_rate))
    model.add(GRU(units // 2, return_sequences=False))
    model.add(Dense(1))

    model.compile(optimizer=optimizer, loss='mean_squared_error')

    early_stop = EarlyStopping(monitor='val_loss', patience=10)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=1, callbacks=[early_stop, reduce_lr])

    test_predict = model.predict(X_test)
    return model, test_predict, history

# Preparing data for 'Avg_Usr'
feature = 'Avg_Usr'

# Normalize the 'Avg_Usr' data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[[feature]])

# Split the data into training and test sets (80% train, 20% test)
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[:train_size], scaled_data[train_size:]

# Create dataset for GRU (look_back=3)
look_back = 3
X_train, y_train = create_dataset(train, look_back=look_back)
X_test, y_test = create_dataset(test, look_back=look_back)

# Reshape input data to 3D (samples, timesteps, features) for GRU input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Train the best model directly with known parameters
units = 50
dropout_rate = 0.4
batch_size = 64
epochs = 50
optimizer = 'rmsprop'

# Train GRU model
model, test_predict, history = train_gru_model(X_train, y_train, X_test, y_test, units, dropout_rate, batch_size, epochs, optimizer)

# Calculate MSE with normalized data
mse = mean_squared_error(y_test, test_predict)
print(f'MSE (normalized): {mse}')
# Out:
# Epoch 1/50
# 5/5 [==============================] - 8s 360ms/step - loss: 0.1444 - val_loss: 0.0303 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0259 - val_loss: 0.0039 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0173 - val_loss: 0.0045 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0146 - val_loss: 0.0022 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0128 - val_loss: 0.0021 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0108 - val_loss: 0.0031 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0078 - val_loss: 0.0021 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 0.0121 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0086 - val_loss: 0.0025 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0059 - val_loss: 0.0030 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0061 - val_loss: 0.0023 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0075 - val_loss: 0.0024 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0060 - val_loss: 0.0067 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0054 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0024 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.005841413534184234

# %%
# Plot the best model's predictions with actual values
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual', color='blue')
plt.plot(test_predict, label='Predicted', color='red')
plt.title(f'Actual vs Predicted for {feature} using GRU')
plt.xlabel('Time')
plt.ylabel(f'{feature}')
plt.legend()
plt.show()

# %%
# Function to create dataset matrix for GRU
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), :])
        Y.append(dataset[i + look_back, :])
    return np.array(X), np.array(Y)

# Function to build and train GRU model with given hyperparameters
def train_gru_model(X_train, y_train, X_test, y_test, units, dropout_rate, batch_size, epochs, optimizer):
    model = Sequential()
    model.add(GRU(units, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(dropout_rate))
    model.add(GRU(units // 2, return_sequences=False))
    model.add(Dense(1))

    model.compile(optimizer=optimizer, loss='mean_squared_error')

    early_stop = EarlyStopping(monitor='val_loss', patience=10)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=1, callbacks=[early_stop, reduce_lr])

    test_predict = model.predict(X_test)
    return model, test_predict, history

# Preparing data for 'Avg_Usr'
feature = 'Avg_Usr'

# Normalize the 'Avg_Usr' data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[[feature]])

# Split the data into training and test sets (80% train, 20% test)
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[:train_size], scaled_data[train_size:]

# Create dataset for GRU (look_back=3)
look_back = 3
X_train, y_train = create_dataset(train, look_back=look_back)
X_test, y_test = create_dataset(test, look_back=look_back)

# Reshape input data to 3D (samples, timesteps, features) for GRU input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Train the best model directly with known parameters
units = 50
dropout_rate = 0.4
batch_size = 64
epochs = 50
optimizer = 'adam'

# Train GRU model
model, test_predict, history = train_gru_model(X_train, y_train, X_test, y_test, units, dropout_rate, batch_size, epochs, optimizer)

# Calculate MSE with normalized data
mse = mean_squared_error(y_test, test_predict)
print(f'MSE (normalized): {mse}')
# Out:
# Epoch 1/50
# 5/5 [==============================] - 7s 309ms/step - loss: 0.1487 - val_loss: 0.0890 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0495 - val_loss: 0.0094 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0160 - val_loss: 0.0082 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0265 - val_loss: 0.0094 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0198 - val_loss: 0.0019 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0115 - val_loss: 0.0068 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0143 - val_loss: 0.0092 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0130 - val_loss: 0.0043 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 0.0021 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0087 - val_loss: 0.0025 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0083 - val_loss: 0.0023 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0075 - val_loss: 0.0022 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0063 - val_loss: 0.0024 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0027 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 0.0024 - lr: 0.0010
# 3/3 [==============================] - 3s 2ms/step
# MSE (normalized): 0.006542440550184036

# %%
# Plot the best model's predictions with actual values
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual', color='blue')
plt.plot(test_predict, label='Predicted', color='red')
plt.title(f'Actual vs Predicted for {feature} using GRU')
plt.xlabel('Time')
plt.ylabel(f'{feature}')
plt.legend()
plt.show()

# %%
# Function to create dataset matrix for GRU
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), :])
        Y.append(dataset[i + look_back, :])
    return np.array(X), np.array(Y)

# Function to build and train GRU model with given hyperparameters
def train_gru_model(X_train, y_train, X_test, y_test, units, dropout_rate, batch_size, epochs, optimizer):
    model = Sequential()
    model.add(GRU(units, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(dropout_rate))
    model.add(GRU(units // 2, return_sequences=False))
    model.add(Dense(1))

    model.compile(optimizer=optimizer, loss='mean_squared_error')

    early_stop = EarlyStopping(monitor='val_loss', patience=10)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=1, callbacks=[early_stop, reduce_lr])

    test_predict = model.predict(X_test)
    return model, test_predict, history

# Preparing data for 'Avg_Usr'
feature = 'Avg_Usr'

# Normalize the 'Avg_Usr' data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[[feature]])

# %%
# Split the data into training and test sets (80% train, 20% test)
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[:train_size], scaled_data[train_size:]

# Create dataset for GRU (look_back=3)
look_back = 3
X_train, y_train = create_dataset(train, look_back=look_back)
X_test, y_test = create_dataset(test, look_back=look_back)

# Reshape input data to 3D (samples, timesteps, features) for GRU input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Manual hyperparameter tuning loop
best_mse = float('inf')
best_params = {}
best_model = None
best_history = None

# Loop through different hyperparameter configurations
for units in [50, 100, 150]:
    for dropout_rate in [0.2, 0.3, 0.4]:
        for batch_size in [32, 64]:
            for epochs in [50, 100, 150]:
                for optimizer in ['adam', 'rmsprop']:
                    print(f'Training with units={units}, dropout_rate={dropout_rate}, batch_size={batch_size}, epochs={epochs}, optimizer={optimizer}')
                    model, test_predict, history = train_gru_model(X_train, y_train, X_test, y_test, units, dropout_rate, batch_size, epochs, optimizer)
                    
                    # Calculate MSE with normalized data
                    mse = mean_squared_error(y_test, test_predict)
                    print(f'MSE (normalized): {mse}')
                    
                    # Track the best model
                    if mse < best_mse:
                        best_mse = mse
                        best_params = {'units': units, 'dropout_rate': dropout_rate, 'batch_size': batch_size, 'epochs': epochs, 'optimizer': optimizer}
                        best_model = model
                        best_history = history

print(f'Best MSE (normalized): {best_mse} with params: {best_params}')

# Predict with the best model
best_test_predict = best_model.predict(X_test)
# Out:
# Training with units=50, dropout_rate=0.2, batch_size=32, epochs=50, optimizer=adam
# Epoch 1/50
# 9/9 [==============================] - 10s 166ms/step - loss: 0.1425 - val_loss: 0.0398 - lr: 0.0010
# Epoch 2/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0227 - val_loss: 0.0100 - lr: 0.0010
# Epoch 3/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0241 - val_loss: 0.0026 - lr: 0.0010
# Epoch 4/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0115 - val_loss: 0.0063 - lr: 0.0010
# Epoch 5/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0114 - val_loss: 0.0040 - lr: 0.0010
# Epoch 6/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0021 - lr: 0.0010
# Epoch 7/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0022 - lr: 0.0010
# Epoch 8/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 0.0024 - lr: 0.0010
# Epoch 9/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0025 - lr: 0.0010
# Epoch 10/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0024 - lr: 0.0010
# Epoch 11/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 0.0024 - lr: 0.0010
# Epoch 12/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0024 - lr: 0.0010
# Epoch 13/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 0.0024 - lr: 0.0010
# Epoch 14/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 0.0024 - lr: 0.0010
# Epoch 15/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0042 - val_loss: 0.0025 - lr: 0.0010
# Epoch 16/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 0.0024 - lr: 0.0010
# 3/3 [==============================] - 2s 3ms/step
# MSE (normalized): 0.005731432041447961
# Training with units=50, dropout_rate=0.2, batch_size=32, epochs=50, optimizer=rmsprop
# Epoch 1/50
# 9/9 [==============================] - 9s 166ms/step - loss: 0.0900 - val_loss: 0.0109 - lr: 0.0010
# Epoch 2/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0167 - val_loss: 0.0122 - lr: 0.0010
# Epoch 3/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0127 - val_loss: 0.0038 - lr: 0.0010
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0022 - lr: 0.0010
# Epoch 5/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0061 - val_loss: 0.0023 - lr: 0.0010
# Epoch 6/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0023 - lr: 0.0010
# Epoch 7/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0036 - lr: 0.0010
# Epoch 8/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0024 - lr: 0.0010
# Epoch 9/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0041 - val_loss: 0.0063 - lr: 0.0010
# Epoch 10/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0054 - val_loss: 0.0041 - lr: 0.0010
# Epoch 11/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0049 - val_loss: 0.0024 - lr: 0.0010
# Epoch 12/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0111 - lr: 0.0010
# Epoch 13/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0050 - lr: 0.0010
# Epoch 14/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0033 - lr: 0.0010
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000015ED986AD40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 1s 5ms/step
# MSE (normalized): 0.008273473176049855
# Training with units=50, dropout_rate=0.2, batch_size=32, epochs=100, optimizer=adam
# Epoch 1/100
# 9/9 [==============================] - 10s 160ms/step - loss: 0.1516 - val_loss: 0.0758 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0319 - val_loss: 0.0021 - lr: 0.0010
# Epoch 3/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0247 - val_loss: 0.0068 - lr: 0.0010
# Epoch 4/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0142 - val_loss: 0.0064 - lr: 0.0010
# Epoch 5/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0134 - val_loss: 0.0075 - lr: 0.0010
# Epoch 6/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 0.0021 - lr: 0.0010
# Epoch 7/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0081 - val_loss: 0.0021 - lr: 0.0010
# Epoch 8/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0060 - val_loss: 0.0029 - lr: 0.0010
# Epoch 9/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0048 - val_loss: 0.0023 - lr: 0.0010
# Epoch 10/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0023 - lr: 0.0010
# Epoch 11/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0024 - lr: 0.0010
# Epoch 12/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0024 - lr: 0.0010
# Epoch 13/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0025 - lr: 0.0010
# Epoch 14/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0039 - val_loss: 0.0025 - lr: 0.0010
# Epoch 15/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0039 - val_loss: 0.0023 - lr: 0.0010
# Epoch 16/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0041 - val_loss: 0.0023 - lr: 0.0010
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000015ECC97F880> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 1s 22ms/step
# MSE (normalized): 0.005665275225455224
# Training with units=50, dropout_rate=0.2, batch_size=32, epochs=100, optimizer=rmsprop
# Epoch 1/100
# 9/9 [==============================] - 10s 163ms/step - loss: 0.0875 - val_loss: 0.0137 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0154 - val_loss: 0.0025 - lr: 0.0010
# Epoch 3/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0104 - val_loss: 0.0020 - lr: 0.0010
# Epoch 4/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 0.0039 - lr: 0.0010
# Epoch 5/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0055 - val_loss: 0.0025 - lr: 0.0010
# Epoch 6/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0043 - val_loss: 0.0027 - lr: 0.0010
# Epoch 7/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 0.0028 - lr: 0.0010
# Epoch 8/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0051 - val_loss: 0.0024 - lr: 0.0010
# Epoch 9/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0062 - lr: 0.0010
# Epoch 10/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0048 - val_loss: 0.0078 - lr: 0.0010
# Epoch 11/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0028 - lr: 0.0010
# Epoch 12/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0026 - lr: 0.0010
# Epoch 13/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0041 - val_loss: 0.0032 - lr: 0.0010
# 3/3 [==============================] - 1s 2ms/step
# MSE (normalized): 0.0074564811945880315
# Training with units=50, dropout_rate=0.2, batch_size=32, epochs=150, optimizer=adam
# Epoch 1/150
# 9/9 [==============================] - 10s 333ms/step - loss: 0.2043 - val_loss: 0.0989 - lr: 0.0010
# Epoch 2/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0393 - val_loss: 0.0019 - lr: 0.0010
# Epoch 3/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0303 - val_loss: 0.0065 - lr: 0.0010
# Epoch 4/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0189 - val_loss: 0.0050 - lr: 0.0010
# Epoch 5/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0152 - val_loss: 0.0072 - lr: 0.0010
# Epoch 6/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0112 - val_loss: 0.0023 - lr: 0.0010
# Epoch 7/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0021 - lr: 0.0010
# Epoch 8/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0022 - lr: 0.0010
# Epoch 9/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0053 - val_loss: 0.0027 - lr: 0.0010
# Epoch 10/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0023 - lr: 0.0010
# Epoch 11/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0043 - val_loss: 0.0024 - lr: 0.0010
# Epoch 12/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 0.0024 - lr: 0.0010
# 3/3 [==============================] - 1s 2ms/step
# MSE (normalized): 0.005956697784532763
# Training with units=50, dropout_rate=0.2, batch_size=32, epochs=150, optimizer=rmsprop
# Epoch 1/150
# 9/9 [==============================] - 8s 160ms/step - loss: 0.0879 - val_loss: 0.0063 - lr: 0.0010
# Epoch 2/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0146 - val_loss: 0.0024 - lr: 0.0010
# Epoch 3/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0107 - val_loss: 0.0065 - lr: 0.0010
# Epoch 4/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0071 - val_loss: 0.0022 - lr: 0.0010
# Epoch 5/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0040 - lr: 0.0010
# Epoch 6/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0024 - lr: 0.0010
# Epoch 7/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 0.0035 - lr: 0.0010
# Epoch 8/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0081 - lr: 0.0010
# Epoch 9/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0025 - lr: 0.0010
# Epoch 10/150
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0045 - val_loss: 0.0062 - lr: 0.0010
# Epoch 11/150
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0050 - val_loss: 0.0113 - lr: 0.0010
# Epoch 12/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0024 - lr: 0.0010
# Epoch 13/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0024 - lr: 0.0010
# Epoch 14/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0032 - lr: 0.0010
# 3/3 [==============================] - 2s 2ms/step
# MSE (normalized): 0.005894661387552287
# Training with units=50, dropout_rate=0.2, batch_size=64, epochs=50, optimizer=adam
# Epoch 1/50
# 5/5 [==============================] - 10s 365ms/step - loss: 0.2063 - val_loss: 0.1462 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0815 - val_loss: 0.0315 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0223 - val_loss: 0.0022 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0224 - val_loss: 0.0127 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0264 - val_loss: 0.0060 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0164 - val_loss: 0.0020 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0118 - val_loss: 0.0055 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0117 - val_loss: 0.0059 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0096 - val_loss: 0.0039 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0084 - val_loss: 0.0023 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0072 - val_loss: 0.0021 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0063 - val_loss: 0.0021 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0059 - val_loss: 0.0022 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0022 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0046 - val_loss: 0.0022 - lr: 0.0010
# Epoch 16/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 0.0023 - lr: 0.0010
# 3/3 [==============================] - 2s 4ms/step
# MSE (normalized): 0.006033595608727304
# Training with units=50, dropout_rate=0.2, batch_size=64, epochs=50, optimizer=rmsprop
# Epoch 1/50
# 5/5 [==============================] - 9s 318ms/step - loss: 0.1861 - val_loss: 0.1216 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0679 - val_loss: 0.0260 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0251 - val_loss: 0.0067 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0166 - val_loss: 0.0056 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0145 - val_loss: 0.0022 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0122 - val_loss: 0.0045 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0105 - val_loss: 0.0047 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0021 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0039 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0131 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0028 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0041 - val_loss: 0.0031 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0039 - val_loss: 0.0036 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0062 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0056 - val_loss: 0.0024 - lr: 0.0010
# Epoch 16/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0027 - lr: 0.0010
# Epoch 17/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0069 - lr: 0.0010
# Epoch 18/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0033 - lr: 0.0010
# 3/3 [==============================] - 1s 2ms/step
# MSE (normalized): 0.005927189457798475
# Training with units=50, dropout_rate=0.2, batch_size=64, epochs=100, optimizer=adam
# Epoch 1/100
# 5/5 [==============================] - 11s 329ms/step - loss: 0.2881 - val_loss: 0.2581 - lr: 0.0010
# Epoch 2/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1611 - val_loss: 0.1252 - lr: 0.0010
# Epoch 3/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0804 - val_loss: 0.0415 - lr: 0.0010
# Epoch 4/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0347 - val_loss: 0.0037 - lr: 0.0010
# Epoch 5/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0250 - val_loss: 0.0044 - lr: 0.0010
# Epoch 6/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0300 - val_loss: 0.0044 - lr: 0.0010
# Epoch 7/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0245 - val_loss: 0.0018 - lr: 0.0010
# Epoch 8/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0189 - val_loss: 0.0052 - lr: 0.0010
# Epoch 9/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0176 - val_loss: 0.0092 - lr: 0.0010
# Epoch 10/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0167 - val_loss: 0.0081 - lr: 0.0010
# Epoch 11/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0144 - val_loss: 0.0036 - lr: 0.0010
# Epoch 12/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0116 - val_loss: 0.0021 - lr: 0.0010
# Epoch 13/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0110 - val_loss: 0.0020 - lr: 0.0010
# Epoch 14/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0098 - val_loss: 0.0020 - lr: 0.0010
# Epoch 15/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0089 - val_loss: 0.0023 - lr: 0.0010
# Epoch 16/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0075 - val_loss: 0.0024 - lr: 0.0010
# Epoch 17/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 0.0023 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.007558896794036893
# Training with units=50, dropout_rate=0.2, batch_size=64, epochs=100, optimizer=rmsprop
# Epoch 1/100
# 5/5 [==============================] - 10s 315ms/step - loss: 0.1094 - val_loss: 0.0434 - lr: 0.0010
# Epoch 2/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0263 - val_loss: 0.0020 - lr: 0.0010
# Epoch 3/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0131 - val_loss: 0.0047 - lr: 0.0010
# Epoch 4/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0110 - val_loss: 0.0020 - lr: 0.0010
# Epoch 5/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0090 - val_loss: 0.0021 - lr: 0.0010
# Epoch 6/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0021 - lr: 0.0010
# Epoch 7/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0037 - lr: 0.0010
# Epoch 8/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0052 - lr: 0.0010
# Epoch 9/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0090 - lr: 0.0010
# Epoch 10/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0045 - lr: 0.0010
# Epoch 11/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0023 - lr: 0.0010
# Epoch 12/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0023 - lr: 0.0010
# 3/3 [==============================] - 1s 4ms/step
# MSE (normalized): 0.005970326468113195
# Training with units=50, dropout_rate=0.2, batch_size=64, epochs=150, optimizer=adam
# Epoch 1/150
# 5/5 [==============================] - 11s 455ms/step - loss: 0.1912 - val_loss: 0.1395 - lr: 0.0010
# Epoch 2/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0799 - val_loss: 0.0328 - lr: 0.0010
# Epoch 3/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0247 - val_loss: 0.0019 - lr: 0.0010
# Epoch 4/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0230 - val_loss: 0.0098 - lr: 0.0010
# Epoch 5/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0276 - val_loss: 0.0043 - lr: 0.0010
# Epoch 6/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0158 - val_loss: 0.0024 - lr: 0.0010
# Epoch 7/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0119 - val_loss: 0.0072 - lr: 0.0010
# Epoch 8/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0139 - val_loss: 0.0086 - lr: 0.0010
# Epoch 9/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0115 - val_loss: 0.0051 - lr: 0.0010
# Epoch 10/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0084 - val_loss: 0.0023 - lr: 0.0010
# Epoch 11/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0078 - val_loss: 0.0021 - lr: 0.0010
# Epoch 12/150
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0068 - val_loss: 0.0021 - lr: 0.0010
# Epoch 13/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0058 - val_loss: 0.0023 - lr: 0.0010
# 3/3 [==============================] - 1s 2ms/step
# MSE (normalized): 0.007215855258481596
# Training with units=50, dropout_rate=0.2, batch_size=64, epochs=150, optimizer=rmsprop
# Epoch 1/150
# 5/5 [==============================] - 10s 683ms/step - loss: 0.1843 - val_loss: 0.1114 - lr: 0.0010
# Epoch 2/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0611 - val_loss: 0.0271 - lr: 0.0010
# Epoch 3/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0236 - val_loss: 0.0079 - lr: 0.0010
# Epoch 4/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0165 - val_loss: 0.0042 - lr: 0.0010
# Epoch 5/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0125 - val_loss: 0.0057 - lr: 0.0010
# Epoch 6/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0124 - val_loss: 0.0019 - lr: 0.0010
# Epoch 7/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0092 - val_loss: 0.0036 - lr: 0.0010
# Epoch 8/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0069 - val_loss: 0.0052 - lr: 0.0010
# Epoch 9/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0066 - val_loss: 0.0042 - lr: 0.0010
# Epoch 10/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0022 - lr: 0.0010
# Epoch 11/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0045 - val_loss: 0.0023 - lr: 0.0010
# Epoch 12/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0041 - lr: 0.0010
# Epoch 13/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0041 - val_loss: 0.0039 - lr: 0.0010
# Epoch 14/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0148 - lr: 0.0010
# Epoch 15/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0063 - val_loss: 0.0034 - lr: 0.0010
# Epoch 16/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0043 - val_loss: 0.0043 - lr: 0.0010
# 3/3 [==============================] - 2s 4ms/step
# MSE (normalized): 0.010116820051532456
# Training with units=50, dropout_rate=0.3, batch_size=32, epochs=50, optimizer=adam
# Epoch 1/50
# 9/9 [==============================] - 8s 142ms/step - loss: 0.1177 - val_loss: 0.0267 - lr: 0.0010
# Epoch 2/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0200 - val_loss: 0.0118 - lr: 0.0010
# Epoch 3/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0216 - val_loss: 0.0020 - lr: 0.0010
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0117 - val_loss: 0.0073 - lr: 0.0010
# Epoch 5/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0026 - lr: 0.0010
# Epoch 6/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0022 - lr: 0.0010
# Epoch 7/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0026 - lr: 0.0010
# Epoch 8/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0060 - val_loss: 0.0026 - lr: 0.0010
# Epoch 9/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0024 - lr: 0.0010
# Epoch 10/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0052 - val_loss: 0.0024 - lr: 0.0010
# Epoch 11/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0050 - val_loss: 0.0024 - lr: 0.0010
# Epoch 12/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 0.0025 - lr: 0.0010
# Epoch 13/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0024 - lr: 0.0010
# 3/3 [==============================] - 2s 6ms/step
# MSE (normalized): 0.005734708801713108
# Training with units=50, dropout_rate=0.3, batch_size=32, epochs=50, optimizer=rmsprop
# Epoch 1/50
# 9/9 [==============================] - 11s 173ms/step - loss: 0.0882 - val_loss: 0.0106 - lr: 0.0010
# Epoch 2/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0159 - val_loss: 0.0022 - lr: 0.0010
# Epoch 3/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0112 - val_loss: 0.0052 - lr: 0.0010
# Epoch 4/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0026 - lr: 0.0010
# Epoch 5/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0024 - lr: 0.0010
# Epoch 6/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0103 - lr: 0.0010
# Epoch 7/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0037 - lr: 0.0010
# Epoch 8/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0024 - lr: 0.0010
# Epoch 9/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0041 - lr: 0.0010
# Epoch 10/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0067 - lr: 0.0010
# Epoch 11/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0026 - lr: 0.0010
# Epoch 12/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0025 - lr: 0.0010
# 3/3 [==============================] - 2s 3ms/step
# MSE (normalized): 0.00626740378259426
# Training with units=50, dropout_rate=0.3, batch_size=32, epochs=100, optimizer=adam
# Epoch 1/100
# 9/9 [==============================] - 10s 157ms/step - loss: 0.1428 - val_loss: 0.0433 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0237 - val_loss: 0.0077 - lr: 0.0010
# Epoch 3/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0221 - val_loss: 0.0020 - lr: 0.0010
# Epoch 4/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0120 - val_loss: 0.0066 - lr: 0.0010
# Epoch 5/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0032 - lr: 0.0010
# Epoch 6/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0086 - val_loss: 0.0021 - lr: 0.0010
# Epoch 7/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0063 - val_loss: 0.0023 - lr: 0.0010
# Epoch 8/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0059 - val_loss: 0.0024 - lr: 0.0010
# Epoch 9/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0024 - lr: 0.0010
# Epoch 10/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 0.0023 - lr: 0.0010
# Epoch 11/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0048 - val_loss: 0.0024 - lr: 0.0010
# Epoch 12/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0050 - val_loss: 0.0024 - lr: 0.0010
# Epoch 13/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0025 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.005649532567220222
# Training with units=50, dropout_rate=0.3, batch_size=32, epochs=100, optimizer=rmsprop
# Epoch 1/100
# 9/9 [==============================] - 11s 184ms/step - loss: 0.0689 - val_loss: 0.0037 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0129 - val_loss: 0.0054 - lr: 0.0010
# Epoch 3/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0093 - val_loss: 0.0054 - lr: 0.0010
# Epoch 4/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0080 - lr: 0.0010
# Epoch 5/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0060 - val_loss: 0.0057 - lr: 0.0010
# Epoch 6/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0048 - val_loss: 0.0028 - lr: 0.0010
# Epoch 7/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0053 - val_loss: 0.0094 - lr: 0.0010
# Epoch 8/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0031 - lr: 0.0010
# Epoch 9/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0088 - lr: 0.0010
# Epoch 10/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0064 - lr: 0.0010
# Epoch 11/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0116 - lr: 0.0010
# Epoch 12/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0058 - val_loss: 0.0023 - lr: 0.0010
# Epoch 13/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0024 - lr: 0.0010
# Epoch 14/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0045 - val_loss: 0.0041 - lr: 0.0010
# Epoch 15/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0051 - val_loss: 0.0045 - lr: 0.0010
# Epoch 16/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0037 - lr: 0.0010
# Epoch 17/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0136 - lr: 0.0010
# Epoch 18/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0049 - lr: 0.0010
# Epoch 19/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 0.0038 - lr: 0.0010
# Epoch 20/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0027 - lr: 0.0010
# Epoch 21/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0120 - lr: 0.0010
# Epoch 22/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0034 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.00570146103734554
# Training with units=50, dropout_rate=0.3, batch_size=32, epochs=150, optimizer=adam
# Epoch 1/150
# 9/9 [==============================] - 10s 181ms/step - loss: 0.1969 - val_loss: 0.0958 - lr: 0.0010
# Epoch 2/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0395 - val_loss: 0.0020 - lr: 0.0010
# Epoch 3/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0296 - val_loss: 0.0051 - lr: 0.0010
# Epoch 4/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0181 - val_loss: 0.0054 - lr: 0.0010
# Epoch 5/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0138 - val_loss: 0.0067 - lr: 0.0010
# Epoch 6/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0112 - val_loss: 0.0023 - lr: 0.0010
# Epoch 7/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0021 - lr: 0.0010
# Epoch 8/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0024 - lr: 0.0010
# Epoch 9/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0023 - lr: 0.0010
# Epoch 10/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0025 - lr: 0.0010
# Epoch 11/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0045 - val_loss: 0.0025 - lr: 0.0010
# Epoch 12/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0025 - lr: 0.0010
# 3/3 [==============================] - 1s 2ms/step
# MSE (normalized): 0.005677134517392458
# Training with units=50, dropout_rate=0.3, batch_size=32, epochs=150, optimizer=rmsprop
# Epoch 1/150
# 9/9 [==============================] - 11s 182ms/step - loss: 0.1219 - val_loss: 0.0338 - lr: 0.0010
# Epoch 2/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0240 - val_loss: 0.0032 - lr: 0.0010
# Epoch 3/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0158 - val_loss: 0.0019 - lr: 0.0010
# Epoch 4/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0108 - val_loss: 0.0069 - lr: 0.0010
# Epoch 5/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0083 - val_loss: 0.0121 - lr: 0.0010
# Epoch 6/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0071 - val_loss: 0.0038 - lr: 0.0010
# Epoch 7/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0029 - lr: 0.0010
# Epoch 8/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0065 - lr: 0.0010
# Epoch 9/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0051 - lr: 0.0010
# Epoch 10/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0068 - lr: 0.0010
# Epoch 11/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0024 - lr: 0.0010
# Epoch 12/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0052 - val_loss: 0.0029 - lr: 0.0010
# Epoch 13/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0038 - lr: 0.0010
# 3/3 [==============================] - 1s 2ms/step
# MSE (normalized): 0.008938593129216799
# Training with units=50, dropout_rate=0.3, batch_size=64, epochs=50, optimizer=adam
# Epoch 1/50
# 5/5 [==============================] - 10s 335ms/step - loss: 0.2375 - val_loss: 0.1710 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0976 - val_loss: 0.0454 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0308 - val_loss: 0.0020 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0254 - val_loss: 0.0118 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0330 - val_loss: 0.0080 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0218 - val_loss: 0.0019 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0153 - val_loss: 0.0071 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0157 - val_loss: 0.0104 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0150 - val_loss: 0.0074 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0125 - val_loss: 0.0031 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0097 - val_loss: 0.0022 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0096 - val_loss: 0.0025 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0091 - val_loss: 0.0021 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0023 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0061 - val_loss: 0.0026 - lr: 0.0010
# Epoch 16/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0024 - lr: 0.0010
# 3/3 [==============================] - 1s 2ms/step
# MSE (normalized): 0.0068681339655279686
# Training with units=50, dropout_rate=0.3, batch_size=64, epochs=50, optimizer=rmsprop
# Epoch 1/50
# 5/5 [==============================] - 9s 476ms/step - loss: 0.1834 - val_loss: 0.0696 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0422 - val_loss: 0.0092 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0202 - val_loss: 0.0032 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0180 - val_loss: 0.0034 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0152 - val_loss: 0.0092 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0137 - val_loss: 0.0020 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0102 - val_loss: 0.0120 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0100 - val_loss: 0.0042 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0076 - val_loss: 0.0025 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0062 - val_loss: 0.0022 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0061 - val_loss: 0.0023 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0071 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0064 - val_loss: 0.0038 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0075 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0027 - lr: 0.0010
# Epoch 16/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0049 - val_loss: 0.0025 - lr: 0.0010
# 3/3 [==============================] - 2s 4ms/step
# MSE (normalized): 0.00655417363386356
# Training with units=50, dropout_rate=0.3, batch_size=64, epochs=100, optimizer=adam
# Epoch 1/100
# 5/5 [==============================] - 9s 502ms/step - loss: 0.2087 - val_loss: 0.1672 - lr: 0.0010
# Epoch 2/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0983 - val_loss: 0.0528 - lr: 0.0010
# Epoch 3/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0352 - val_loss: 0.0038 - lr: 0.0010
# Epoch 4/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0204 - val_loss: 0.0070 - lr: 0.0010
# Epoch 5/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0277 - val_loss: 0.0065 - lr: 0.0010
# Epoch 6/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0208 - val_loss: 0.0018 - lr: 0.0010
# Epoch 7/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0135 - val_loss: 0.0060 - lr: 0.0010
# Epoch 8/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0139 - val_loss: 0.0103 - lr: 0.0010
# Epoch 9/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.0080 - lr: 0.0010
# Epoch 10/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0109 - val_loss: 0.0037 - lr: 0.0010
# Epoch 11/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0084 - val_loss: 0.0021 - lr: 0.0010
# Epoch 12/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0078 - val_loss: 0.0024 - lr: 0.0010
# Epoch 13/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0070 - val_loss: 0.0021 - lr: 0.0010
# Epoch 14/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0063 - val_loss: 0.0025 - lr: 0.0010
# Epoch 15/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0026 - lr: 0.0010
# Epoch 16/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0054 - val_loss: 0.0023 - lr: 0.0010
# 3/3 [==============================] - 2s 3ms/step
# MSE (normalized): 0.00554081498961177
# Training with units=50, dropout_rate=0.3, batch_size=64, epochs=100, optimizer=rmsprop
# Epoch 1/100
# 5/5 [==============================] - 9s 298ms/step - loss: 0.1370 - val_loss: 0.0363 - lr: 0.0010
# Epoch 2/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0291 - val_loss: 0.0041 - lr: 0.0010
# Epoch 3/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0182 - val_loss: 0.0023 - lr: 0.0010
# Epoch 4/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0139 - val_loss: 0.0034 - lr: 0.0010
# Epoch 5/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0121 - val_loss: 0.0021 - lr: 0.0010
# Epoch 6/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0097 - val_loss: 0.0022 - lr: 0.0010
# Epoch 7/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0070 - val_loss: 0.0038 - lr: 0.0010
# Epoch 8/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0061 - val_loss: 0.0038 - lr: 0.0010
# Epoch 9/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0046 - lr: 0.0010
# Epoch 10/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0045 - lr: 0.0010
# Epoch 11/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0048 - lr: 0.0010
# Epoch 12/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0057 - val_loss: 0.0035 - lr: 0.0010
# Epoch 13/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0055 - lr: 0.0010
# Epoch 14/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0042 - lr: 0.0010
# Epoch 15/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0243 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.029364150611922137
# Training with units=50, dropout_rate=0.3, batch_size=64, epochs=150, optimizer=adam
# Epoch 1/150
# 5/5 [==============================] - 9s 247ms/step - loss: 0.1494 - val_loss: 0.0961 - lr: 0.0010
# Epoch 2/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0540 - val_loss: 0.0150 - lr: 0.0010
# Epoch 3/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0162 - val_loss: 0.0047 - lr: 0.0010
# Epoch 4/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0106 - lr: 0.0010
# Epoch 5/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0210 - val_loss: 0.0025 - lr: 0.0010
# Epoch 6/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0042 - lr: 0.0010
# Epoch 7/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0112 - val_loss: 0.0080 - lr: 0.0010
# Epoch 8/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0114 - val_loss: 0.0052 - lr: 0.0010
# Epoch 9/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0088 - val_loss: 0.0021 - lr: 0.0010
# Epoch 10/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0082 - val_loss: 0.0025 - lr: 0.0010
# Epoch 11/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0074 - val_loss: 0.0022 - lr: 0.0010
# Epoch 12/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0027 - lr: 0.0010
# Epoch 13/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0027 - lr: 0.0010
# Epoch 14/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0023 - lr: 0.0010
# Epoch 15/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0023 - lr: 0.0010
# Epoch 16/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0025 - lr: 0.0010
# Epoch 17/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0024 - lr: 0.0010
# Epoch 18/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0024 - lr: 0.0010
# Epoch 19/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0026 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.006306132134410378
# Training with units=50, dropout_rate=0.3, batch_size=64, epochs=150, optimizer=rmsprop
# Epoch 1/150
# 5/5 [==============================] - 8s 354ms/step - loss: 0.1492 - val_loss: 0.0697 - lr: 0.0010
# Epoch 2/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0404 - val_loss: 0.0218 - lr: 0.0010
# Epoch 3/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0220 - val_loss: 0.0028 - lr: 0.0010
# Epoch 4/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0155 - val_loss: 0.0027 - lr: 0.0010
# Epoch 5/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0142 - val_loss: 0.0021 - lr: 0.0010
# Epoch 6/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0110 - val_loss: 0.0037 - lr: 0.0010
# Epoch 7/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0098 - val_loss: 0.0078 - lr: 0.0010
# Epoch 8/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0029 - lr: 0.0010
# Epoch 9/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0066 - val_loss: 0.0046 - lr: 0.0010
# Epoch 10/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0072 - val_loss: 0.0049 - lr: 0.0010
# Epoch 11/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0023 - lr: 0.0010
# Epoch 12/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0024 - lr: 0.0010
# Epoch 13/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0023 - lr: 0.0010
# Epoch 14/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0025 - lr: 0.0010
# Epoch 15/150
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0045 - val_loss: 0.0070 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.008786423668805736
# Training with units=50, dropout_rate=0.4, batch_size=32, epochs=50, optimizer=adam
# Epoch 1/50
# 9/9 [==============================] - 14s 296ms/step - loss: 0.2104 - val_loss: 0.1422 - lr: 0.0010
# Epoch 2/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0684 - val_loss: 0.0141 - lr: 0.0010
# Epoch 3/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0235 - val_loss: 0.0045 - lr: 0.0010
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0256 - val_loss: 0.0021 - lr: 0.0010
# Epoch 5/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0173 - val_loss: 0.0075 - lr: 0.0010
# Epoch 6/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0161 - val_loss: 0.0040 - lr: 0.0010
# Epoch 7/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0116 - val_loss: 0.0020 - lr: 0.0010
# Epoch 8/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0088 - val_loss: 0.0022 - lr: 0.0010
# Epoch 9/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 0.0026 - lr: 0.0010
# Epoch 10/50
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0065 - val_loss: 0.0024 - lr: 0.0010
# Epoch 11/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0025 - lr: 0.0010
# Epoch 12/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0060 - val_loss: 0.0024 - lr: 0.0010
# Epoch 13/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0059 - val_loss: 0.0026 - lr: 0.0010
# Epoch 14/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 0.0025 - lr: 0.0010
# Epoch 15/50
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0052 - val_loss: 0.0024 - lr: 0.0010
# Epoch 16/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0024 - lr: 0.0010
# Epoch 17/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0024 - lr: 0.0010
# 3/3 [==============================] - 2s 6ms/step
# MSE (normalized): 0.006059946668949161
# Training with units=50, dropout_rate=0.4, batch_size=32, epochs=50, optimizer=rmsprop
# Epoch 1/50
# 9/9 [==============================] - 11s 268ms/step - loss: 0.1137 - val_loss: 0.0095 - lr: 0.0010
# Epoch 2/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0200 - val_loss: 0.0020 - lr: 0.0010
# Epoch 3/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0145 - val_loss: 0.0030 - lr: 0.0010
# Epoch 4/50
# ...
# Epoch 7/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0029 - lr: 0.0010
# Epoch 8/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0045 - val_loss: 0.0047 - lr: 0.0010
# Epoch 9/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0134 - lr: 0.0010
# Epoch 10/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0073 - lr: 0.0010
# Epoch 11/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0028 - lr: 0.0010
# Epoch 12/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0023 - lr: 0.0010
# Epoch 13/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0045 - val_loss: 0.0030 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.005983463846574719
# Training with units=150, dropout_rate=0.4, batch_size=64, epochs=50, optimizer=adam
# Epoch 1/50
# 5/5 [==============================] - 7s 227ms/step - loss: 0.1498 - val_loss: 0.0167 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0185 - val_loss: 0.0353 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0310 - val_loss: 0.0024 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0088 - val_loss: 0.0161 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0170 - val_loss: 0.0126 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0021 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0056 - val_loss: 0.0053 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0070 - val_loss: 0.0024 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0031 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0023 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0025 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 0.0024 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0024 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0025 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0039 - lr: 0.0010
# Epoch 16/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0050 - val_loss: 0.0025 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.0056154248037352415
# Training with units=150, dropout_rate=0.4, batch_size=64, epochs=50, optimizer=rmsprop
# Epoch 1/50
# 5/5 [==============================] - 6s 227ms/step - loss: 0.0961 - val_loss: 0.0029 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0131 - val_loss: 0.0040 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0084 - val_loss: 0.0081 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0076 - val_loss: 0.0061 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0050 - val_loss: 0.0029 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0025 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0255 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0079 - val_loss: 0.0024 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 0.0026 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0049 - val_loss: 0.0111 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0076 - val_loss: 0.0088 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0067 - val_loss: 0.0025 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0041 - val_loss: 0.0031 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0054 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0026 - lr: 0.0010
# Epoch 16/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 0.0024 - lr: 0.0010
# Epoch 17/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0039 - val_loss: 0.0027 - lr: 0.0010
# Epoch 18/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0086 - val_loss: 0.0026 - lr: 0.0010
# 3/3 [==============================] - 1s 4ms/step
# MSE (normalized): 0.005487468868333238
# Training with units=150, dropout_rate=0.4, batch_size=64, epochs=100, optimizer=adam
# Epoch 1/100
# 5/5 [==============================] - 7s 233ms/step - loss: 0.1748 - val_loss: 0.0358 - lr: 0.0010
# Epoch 2/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0196 - val_loss: 0.0308 - lr: 0.0010
# Epoch 3/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0382 - val_loss: 0.0119 - lr: 0.0010
# Epoch 4/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0112 - val_loss: 0.0073 - lr: 0.0010
# Epoch 5/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0120 - val_loss: 0.0156 - lr: 0.0010
# Epoch 6/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0127 - val_loss: 0.0047 - lr: 0.0010
# Epoch 7/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0054 - val_loss: 0.0041 - lr: 0.0010
# Epoch 8/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - val_loss: 0.0043 - lr: 0.0010
# Epoch 9/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0029 - lr: 0.0010
# Epoch 10/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0042 - lr: 0.0010
# Epoch 11/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0022 - lr: 0.0010
# Epoch 12/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0040 - val_loss: 0.0027 - lr: 0.0010
# Epoch 13/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0047 - val_loss: 0.0025 - lr: 0.0010
# Epoch 14/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 0.0025 - lr: 0.0010
# Epoch 15/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0049 - val_loss: 0.0024 - lr: 0.0010
# Epoch 16/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0023 - lr: 0.0010
# Epoch 17/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0032 - lr: 0.0010
# Epoch 18/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0029 - lr: 0.0010
# Epoch 19/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0039 - val_loss: 0.0025 - lr: 0.0010
# Epoch 20/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0023 - lr: 0.0010
# Epoch 21/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0026 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.005578020487681704
# Training with units=150, dropout_rate=0.4, batch_size=64, epochs=100, optimizer=rmsprop
# Epoch 1/100
# 5/5 [==============================] - 7s 289ms/step - loss: 0.0920 - val_loss: 0.0054 - lr: 0.0010
# Epoch 2/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0110 - val_loss: 0.0101 - lr: 0.0010
# Epoch 3/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0094 - val_loss: 0.0024 - lr: 0.0010
# Epoch 4/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0066 - val_loss: 0.0027 - lr: 0.0010
# Epoch 5/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 0.0035 - lr: 0.0010
# Epoch 6/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0061 - val_loss: 0.0045 - lr: 0.0010
# Epoch 7/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0075 - lr: 0.0010
# Epoch 8/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0056 - val_loss: 0.0072 - lr: 0.0010
# Epoch 9/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0064 - val_loss: 0.0025 - lr: 0.0010
# Epoch 10/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0023 - lr: 0.0010
# Epoch 11/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0033 - lr: 0.0010
# Epoch 12/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0053 - lr: 0.0010
# Epoch 13/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0061 - lr: 0.0010
# Epoch 14/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0107 - lr: 0.0010
# Epoch 15/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0087 - lr: 0.0010
# Epoch 16/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0045 - val_loss: 0.0023 - lr: 0.0010
# Epoch 17/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0111 - lr: 0.0010
# Epoch 18/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0080 - val_loss: 0.0033 - lr: 0.0010
# Epoch 19/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0193 - lr: 0.0010
# Epoch 20/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0036 - lr: 0.0010
# Epoch 21/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0028 - lr: 0.0010
# Epoch 22/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0156 - lr: 0.0010
# Epoch 23/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0087 - val_loss: 0.0024 - lr: 0.0010
# Epoch 24/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0025 - lr: 0.0010
# Epoch 25/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0038 - lr: 0.0010
# Epoch 26/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0041 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.006109414280062627
# Training with units=150, dropout_rate=0.4, batch_size=64, epochs=150, optimizer=adam
# Epoch 1/150
# 5/5 [==============================] - 6s 230ms/step - loss: 0.1629 - val_loss: 0.0239 - lr: 0.0010
# Epoch 2/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0168 - val_loss: 0.0256 - lr: 0.0010
# Epoch 3/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0282 - val_loss: 0.0031 - lr: 0.0010
# Epoch 4/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0081 - val_loss: 0.0123 - lr: 0.0010
# Epoch 5/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0135 - val_loss: 0.0093 - lr: 0.0010
# Epoch 6/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.0021 - lr: 0.0010
# Epoch 7/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0034 - lr: 0.0010
# Epoch 8/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0022 - lr: 0.0010
# Epoch 9/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0023 - lr: 0.0010
# Epoch 10/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0024 - lr: 0.0010
# Epoch 11/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0023 - lr: 0.0010
# Epoch 12/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0045 - val_loss: 0.0023 - lr: 0.0010
# Epoch 13/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0041 - val_loss: 0.0027 - lr: 0.0010
# Epoch 14/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0024 - lr: 0.0010
# Epoch 15/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0024 - lr: 0.0010
# Epoch 16/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0045 - val_loss: 0.0029 - lr: 0.0010
# 3/3 [==============================] - 1s 3ms/step
# MSE (normalized): 0.005879075414440112
# Training with units=150, dropout_rate=0.4, batch_size=64, epochs=150, optimizer=rmsprop
# Epoch 1/150
# 5/5 [==============================] - 7s 233ms/step - loss: 0.1010 - val_loss: 0.0064 - lr: 0.0010
# Epoch 2/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0134 - val_loss: 0.0085 - lr: 0.0010
# Epoch 3/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 0.0053 - lr: 0.0010
# Epoch 4/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0064 - val_loss: 0.0072 - lr: 0.0010
# Epoch 5/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0059 - val_loss: 0.0083 - lr: 0.0010
# Epoch 6/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0060 - val_loss: 0.0063 - lr: 0.0010
# Epoch 7/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0055 - lr: 0.0010
# Epoch 8/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0027 - lr: 0.0010
# Epoch 9/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0164 - lr: 0.0010
# Epoch 10/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0034 - lr: 0.0010
# Epoch 11/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0032 - lr: 0.0010
# Epoch 12/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0032 - lr: 0.0010
# Epoch 13/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0047 - lr: 0.0010
# Epoch 14/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0063 - val_loss: 0.0025 - lr: 0.0010
# Epoch 15/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0045 - val_loss: 0.0085 - lr: 0.0010
# Epoch 16/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0163 - lr: 0.0010
# Epoch 17/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.0023 - lr: 0.0010
# Epoch 18/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 0.0076 - lr: 0.0010
# Epoch 19/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0036 - lr: 0.0010
# Epoch 20/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0038 - lr: 0.0010
# Epoch 21/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0037 - lr: 0.0010
# Epoch 22/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0159 - lr: 0.0010
# Epoch 23/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0077 - val_loss: 0.0082 - lr: 0.0010
# Epoch 24/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0055 - val_loss: 0.0026 - lr: 0.0010
# Epoch 25/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0040 - val_loss: 0.0054 - lr: 0.0010
# Epoch 26/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0037 - val_loss: 0.0028 - lr: 0.0010
# Epoch 27/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0075 - val_loss: 0.0054 - lr: 0.0010
# 3/3 [==============================] - 1s 4ms/step
# MSE (normalized): 0.0073914355188865665
# Best MSE (normalized): 0.005348890725473132 with params: {'units': 150, 'dropout_rate': 0.3, 'batch_size': 32, 'epochs': 100, 'optimizer': 'adam'}
# 3/3 [==============================] - 0s 4ms/step

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
# Load your dataset (adjust the path to where your file is located)
data = pd.read_csv('../../data/Tdata.csv')

# Function to create dataset matrix for SVM
def create_dataset_svm(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), 0])  # Flatten to 1D array for SVM
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Preparing data for 'Avg_Usr'
feature = 'Avg_Usr'
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[[feature]])

# Split the data into training and test sets (80% train, 20% test)
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[:train_size], scaled_data[train_size:]

# SVM Model Prediction
look_back = 3
X_train_svm, y_train_svm = create_dataset_svm(train, look_back=look_back)
X_test_svm, y_test_svm = create_dataset_svm(test, look_back=look_back)

svm_model = SVR(kernel='rbf', C=1, gamma='scale')
svm_model.fit(X_train_svm, y_train_svm)

# Predict with SVM
train_predict_svm = svm_model.predict(X_train_svm)
test_predict_svm = svm_model.predict(X_test_svm)

# Prepare the data for LSTM/GRU hybrid
def create_dataset_hybrid(svm_predictions, original_data, look_back=1):
    X, Y = [], []
    for i in range(len(svm_predictions) - look_back):
        # Combine original time series and SVM predictions as features
        feature_set = np.hstack((original_data[i:(i + look_back)], svm_predictions[i:(i + look_back)].reshape(-1, 1)))
        X.append(feature_set)
        Y.append(original_data[i + look_back, 0])
    return np.array(X), np.array(Y)

# Create dataset for LSTM using SVM predictions
X_train_lstm, y_train_lstm = create_dataset_hybrid(train_predict_svm, train, look_back=look_back)
X_test_lstm, y_test_lstm = create_dataset_hybrid(test_predict_svm, test, look_back=look_back)

# Reshape input data for LSTM (samples, timesteps, features)
X_train_lstm = np.reshape(X_train_lstm, (X_train_lstm.shape[0], X_train_lstm.shape[1], 2))
X_test_lstm = np.reshape(X_test_lstm, (X_test_lstm.shape[0], X_test_lstm.shape[1], 2))

# Function to build and train LSTM and GRU models
def build_lstm_gru_model(input_shape, lstm_units, gru_units, dropout_rate):
    model = Sequential()
    model.add(LSTM(lstm_units, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(dropout_rate))
    model.add(GRU(gru_units, return_sequences=False))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Loop through different hyperparameter configurations
best_mse = float('inf')
best_params = {}
best_model = None

for lstm_units in [50, 100]:
    for gru_units in [50, 100]:
        for dropout_rate in [0.2, 0.3]:
            for batch_size in [32, 64]:
                for epochs in [50, 100]:
                    print(f'Training with LSTM units={lstm_units}, GRU units={gru_units}, dropout_rate={dropout_rate}, batch_size={batch_size}, epochs={epochs}')
                    model = build_lstm_gru_model((look_back, 2), lstm_units, gru_units, dropout_rate)
                    model.fit(X_train_lstm, y_train_lstm, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=1)
                    
                    # Predict
                    test_predict = model.predict(X_test_lstm)
                    
                    # Calculate MSE
                    mse = mean_squared_error(y_test_lstm, test_predict)
                    print(f'MSE: {mse}')
                    
                    if mse < best_mse:
                        best_mse = mse
                        best_params = {'lstm_units': lstm_units, 'gru_units': gru_units, 'dropout_rate': dropout_rate, 'batch_size': batch_size, 'epochs': epochs}
                        best_model = model

print(f'Best MSE: {best_mse} with params: {best_params}')

# Predict with the best model
best_test_predict = best_model.predict(X_test_lstm)

# Invert predictions and actual values back to original scale
best_test_predict = scaler.inverse_transform(best_test_predict)
y_test_lstm = scaler.inverse_transform([y_test_lstm])

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_lstm[0], label='Actual', color='blue')
plt.plot(best_test_predict, label='Predicted', color='red')
plt.title(f'Actual vs Predicted for Avg_Usr using Stacked SVM-LSTM-GRU Model')
plt.xlabel('Time')
plt.ylabel('Avg_Usr')
plt.legend()
plt.show()
# Out:
# Training with LSTM units=50, GRU units=50, dropout_rate=0.2, batch_size=32, epochs=50
# Epoch 1/50
# 9/9 [==============================] - 12s 286ms/step - loss: 0.1335 - val_loss: 0.0399
# Epoch 2/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0204 - val_loss: 0.0100
# Epoch 3/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0216 - val_loss: 0.0013
# Epoch 4/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0119 - val_loss: 0.0067
# Epoch 5/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0098 - val_loss: 0.0014
# Epoch 6/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0063 - val_loss: 0.0013
# Epoch 7/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 8/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 9/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 10/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 11/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 12/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 13/50
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0071 - val_loss: 0.0048
# Epoch 14/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 15/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 16/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 17/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 18/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 19/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 20/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 21/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 22/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 23/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 24/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 25/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 26/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 27/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 28/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 29/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 30/50
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 31/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 32/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 33/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 34/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 35/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 36/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 37/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 38/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 39/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0026 - val_loss: 9.5903e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 41/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 42/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0010
# Epoch 43/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 44/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 9.5197e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 46/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 47/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 48/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0031 - val_loss: 8.5723e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 50/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0013
# 3/3 [==============================] - 3s 5ms/step
# MSE: 0.004982297780999776
# Training with LSTM units=50, GRU units=50, dropout_rate=0.2, batch_size=32, epochs=100
# Epoch 1/100
# 9/9 [==============================] - 14s 299ms/step - loss: 0.1697 - val_loss: 0.0838
# Epoch 2/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0355 - val_loss: 0.0035
# Epoch 3/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0261 - val_loss: 0.0032
# Epoch 4/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0143 - val_loss: 0.0053
# Epoch 5/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0136 - val_loss: 0.0028
# Epoch 6/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0020
# Epoch 7/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0074 - val_loss: 0.0010
# Epoch 8/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0055 - val_loss: 0.0012
# Epoch 9/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 10/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 11/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 12/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 13/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 14/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 15/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0010
# Epoch 16/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 17/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 18/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 19/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 20/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 21/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 22/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 23/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 24/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 9.6228e-04
# Epoch 25/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 9.5626e-04
# Epoch 26/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 27/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 9.3758e-04
# Epoch 28/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 29/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 9.4191e-04
# Epoch 30/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 31/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 32/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 33/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 9.0399e-04
# Epoch 34/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 35/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0030 - val_loss: 9.2441e-04
# Epoch 36/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 37/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0033 - val_loss: 9.3469e-04
# Epoch 38/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 39/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 40/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 41/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 42/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 43/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 44/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 45/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 8.4857e-04
# Epoch 46/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 47/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 8.8228e-04
# Epoch 48/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 9.1840e-04
# Epoch 49/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 50/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 9.1647e-04
# Epoch 51/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 52/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 53/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 54/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 55/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 56/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 8.3945e-04
# Epoch 57/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 58/100
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0029 - val_loss: 8.9150e-04
# Epoch 59/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 60/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0031 - val_loss: 7.9480e-04
# Epoch 61/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 62/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 7.9455e-04
# Epoch 63/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 64/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0024 - val_loss: 9.2378e-04
# Epoch 65/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 66/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 67/100
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0028 - val_loss: 9.7348e-04
# Epoch 68/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 69/100
# 9/9 [==============================] - 0s 49ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 70/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 71/100
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 9.3473e-04
# Epoch 72/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 73/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 74/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0028 - val_loss: 8.3794e-04
# Epoch 75/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 76/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 77/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0026 - val_loss: 8.8221e-04
# Epoch 78/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 9.4723e-04
# Epoch 79/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 80/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 81/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 82/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 83/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 8.9914e-04
# Epoch 84/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 85/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 9.2935e-04
# Epoch 86/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 87/100
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 88/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 7.8597e-04
# Epoch 89/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 90/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 7.1230e-04
# Epoch 91/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 92/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 7.1259e-04
# Epoch 93/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 94/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 95/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 96/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 97/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 98/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 99/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 100/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 6.9577e-04
# 3/3 [==============================] - 2s 3ms/step
# MSE: 0.01010719979177321
# Training with LSTM units=50, GRU units=50, dropout_rate=0.2, batch_size=64, epochs=50
# Epoch 1/50
# 5/5 [==============================] - 16s 715ms/step - loss: 0.2407 - val_loss: 0.2052
# Epoch 2/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1226 - val_loss: 0.0835
# Epoch 3/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0477 - val_loss: 0.0147
# Epoch 4/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0193 - val_loss: 0.0024
# Epoch 5/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0213 - val_loss: 0.0061
# Epoch 6/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0201 - val_loss: 0.0016
# Epoch 7/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0139 - val_loss: 0.0032
# Epoch 8/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0131 - val_loss: 0.0074
# Epoch 9/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0130 - val_loss: 0.0075
# Epoch 10/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0109 - val_loss: 0.0040
# Epoch 11/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0078 - val_loss: 0.0016
# Epoch 12/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0014
# Epoch 13/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0014
# Epoch 14/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 15/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 16/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 17/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 18/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 19/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 20/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 21/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 22/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 23/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 24/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 25/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0020
# Epoch 26/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 27/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0024
# Epoch 28/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 29/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 30/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 31/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 32/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 33/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 34/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 35/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 36/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 37/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 38/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 39/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 40/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 41/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 42/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 43/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 44/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 45/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 46/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 47/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 48/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 49/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 50/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0029 - val_loss: 0.0026
# 3/3 [==============================] - 2s 5ms/step
# MSE: 0.003926330064845368
# Training with LSTM units=50, GRU units=50, dropout_rate=0.2, batch_size=64, epochs=100
# Epoch 1/100
# 5/5 [==============================] - 15s 721ms/step - loss: 0.2081 - val_loss: 0.1634
# Epoch 2/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0941 - val_loss: 0.0464
# Epoch 3/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0285 - val_loss: 0.0012
# Epoch 4/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0200 - val_loss: 0.0082
# Epoch 5/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0237 - val_loss: 0.0036
# Epoch 6/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0152 - val_loss: 0.0015
# Epoch 7/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0118 - val_loss: 0.0060
# Epoch 8/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0134 - val_loss: 0.0060
# Epoch 9/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0101 - val_loss: 0.0013
# Epoch 10/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0078 - val_loss: 0.0020
# Epoch 11/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0083 - val_loss: 0.0023
# Epoch 12/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0066 - val_loss: 0.0010
# Epoch 13/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0060 - val_loss: 0.0022
# Epoch 14/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0057 - val_loss: 0.0019
# Epoch 15/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 16/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 17/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 18/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 19/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 20/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 21/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 22/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 23/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 24/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 25/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 26/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 27/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 28/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 29/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 30/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 31/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 32/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 33/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 34/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 35/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 36/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 37/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 38/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 39/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 40/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 41/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 42/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 43/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 44/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0010
# Epoch 45/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 46/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 47/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 48/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 49/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 50/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 51/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 52/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 53/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 54/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 55/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 56/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0032 - val_loss: 0.0010
# Epoch 57/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 58/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 59/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 60/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 61/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 62/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 63/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0027 - val_loss: 0.0041
# Epoch 64/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 65/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 66/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 67/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 68/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0028 - val_loss: 9.8720e-04
# Epoch 69/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0028 - val_loss: 9.8716e-04
# Epoch 70/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0032 - val_loss: 9.7089e-04
# Epoch 71/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 72/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 73/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 74/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 75/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 76/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0027 - val_loss: 0.0010
# Epoch 77/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0026 - val_loss: 9.5527e-04
# Epoch 78/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 79/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 80/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 81/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 9.8437e-04
# Epoch 82/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 83/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 84/100
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 85/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0024 - val_loss: 9.4394e-04
# Epoch 86/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 87/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 88/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 89/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 90/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 9.0061e-04
# Epoch 91/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 92/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 93/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 94/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 95/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 96/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 9.5051e-04
# Epoch 97/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 98/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0024 - val_loss: 9.2264e-04
# Epoch 99/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 100/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0013
# 3/3 [==============================] - 2s 6ms/step
# MSE: 0.0051802388544600845
# Training with LSTM units=50, GRU units=50, dropout_rate=0.3, batch_size=32, epochs=50
# Epoch 1/50
# 9/9 [==============================] - 13s 219ms/step - loss: 0.1545 - val_loss: 0.0628
# Epoch 2/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0249 - val_loss: 0.0050
# Epoch 3/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0245 - val_loss: 0.0020
# Epoch 4/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0147 - val_loss: 0.0075
# Epoch 5/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0137 - val_loss: 0.0027
# Epoch 6/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0092 - val_loss: 0.0015
# Epoch 7/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0084 - val_loss: 0.0014
# Epoch 8/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0067 - val_loss: 0.0013
# Epoch 9/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0016
# Epoch 10/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 11/50
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 12/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 13/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 14/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0059 - val_loss: 0.0037
# Epoch 15/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0041 - val_loss: 0.0012
# Epoch 16/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 17/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0050 - val_loss: 0.0012
# Epoch 18/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 19/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 20/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 21/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 22/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 23/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 24/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 25/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 26/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 27/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 28/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 29/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0039 - val_loss: 0.0010
# Epoch 30/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 31/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 32/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0010
# Epoch 33/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 34/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 35/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 36/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 37/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 38/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 39/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 40/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 9.7836e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 42/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 8.9212e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 44/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 8.7669e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 46/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 47/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0010
# Epoch 48/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 49/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 50/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0015
# 3/3 [==============================] - 2s 5ms/step
# MSE: 0.004865696626396997
# Training with LSTM units=50, GRU units=50, dropout_rate=0.3, batch_size=32, epochs=100
# Epoch 1/100
# 9/9 [==============================] - 14s 304ms/step - loss: 0.1594 - val_loss: 0.0526
# Epoch 2/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0222 - val_loss: 0.0109
# Epoch 3/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0231 - val_loss: 0.0015
# Epoch 4/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0112 - val_loss: 0.0033
# Epoch 5/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0115 - val_loss: 0.0017
# Epoch 6/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0082 - val_loss: 0.0024
# Epoch 7/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0069 - val_loss: 0.0011
# Epoch 8/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0012
# Epoch 9/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 10/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 0.0011
# Epoch 11/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 12/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0010
# Epoch 13/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 14/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 15/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0010
# Epoch 16/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0035 - val_loss: 0.0010
# Epoch 17/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 18/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 19/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 20/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 21/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 22/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 23/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 24/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 25/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 26/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0040 - val_loss: 0.0010
# Epoch 27/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 28/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 29/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 30/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 31/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 32/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 33/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 34/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 35/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 36/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 37/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0030 - val_loss: 9.4795e-04
# Epoch 38/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 39/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 40/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 41/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 42/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 43/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 9.8053e-04
# Epoch 44/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 45/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 46/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 47/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 48/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 49/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 50/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 51/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 52/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 53/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 54/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0035 - val_loss: 8.7208e-04
# Epoch 55/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 56/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 8.4720e-04
# Epoch 57/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 58/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 59/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 60/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 61/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 62/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 9.5420e-04
# Epoch 63/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 64/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 8.2198e-04
# Epoch 65/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 66/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 9.7134e-04
# Epoch 67/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 68/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 9.0599e-04
# Epoch 69/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 70/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 8.1173e-04
# Epoch 71/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 72/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 73/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 74/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 9.1566e-04
# Epoch 75/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 76/100
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0027 - val_loss: 8.7445e-04
# Epoch 77/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0040 - val_loss: 0.0023
# Epoch 78/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 7.9248e-04
# Epoch 79/100
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 80/100
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 81/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0027 - val_loss: 8.2610e-04
# Epoch 82/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 83/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 84/100
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0026 - val_loss: 7.7104e-04
# Epoch 85/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 86/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 87/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 8.9957e-04
# Epoch 88/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 89/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 90/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 91/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0024 - val_loss: 9.2383e-04
# Epoch 92/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 93/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 8.9190e-04
# Epoch 94/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 95/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 96/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 97/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 98/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 9.7790e-04
# Epoch 99/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 100/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 8.0236e-04
# 3/3 [==============================] - 2s 5ms/step
# MSE: 0.008109431995202927
# Training with LSTM units=50, GRU units=50, dropout_rate=0.3, batch_size=64, epochs=50
# Epoch 1/50
# 5/5 [==============================] - 14s 704ms/step - loss: 0.1982 - val_loss: 0.1664
# Epoch 2/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0990 - val_loss: 0.0549
# Epoch 3/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0323 - val_loss: 0.0021
# Epoch 4/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0198 - val_loss: 0.0129
# Epoch 5/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0301 - val_loss: 0.0081
# Epoch 6/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0212 - val_loss: 0.0012
# Epoch 7/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0133 - val_loss: 0.0068
# Epoch 8/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0162 - val_loss: 0.0102
# Epoch 9/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0158 - val_loss: 0.0073
# Epoch 10/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0125 - val_loss: 0.0025
# Epoch 11/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0090 - val_loss: 0.0012
# Epoch 12/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0079 - val_loss: 0.0013
# Epoch 13/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0072 - val_loss: 0.0012
# Epoch 14/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0065 - val_loss: 0.0014
# Epoch 15/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0053 - val_loss: 0.0016
# Epoch 16/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 17/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 18/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 19/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 20/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 21/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 22/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 23/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 24/50
# ...
# Epoch 96/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 97/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0023 - val_loss: 6.8788e-04
# Epoch 98/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 99/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 100/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0011
# 3/3 [==============================] - 1s 3ms/step
# MSE: 0.007038246796509211
# Training with LSTM units=100, GRU units=100, dropout_rate=0.3, batch_size=64, epochs=50
# Epoch 1/50
# 5/5 [==============================] - 12s 323ms/step - loss: 0.1782 - val_loss: 0.0763
# Epoch 2/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0361 - val_loss: 0.0023
# Epoch 3/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0227 - val_loss: 0.0207
# Epoch 4/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0200 - val_loss: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0099 - val_loss: 0.0083
# Epoch 6/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0112 - val_loss: 0.0027
# Epoch 7/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0072 - val_loss: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0060 - val_loss: 0.0015
# Epoch 9/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0052 - val_loss: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 12/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 13/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 14/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 15/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0036 - val_loss: 0.0012
# Epoch 16/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 17/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 18/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 19/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 20/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 21/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 22/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 23/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 24/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 25/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 26/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 27/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 28/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 29/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 30/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 31/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 32/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 33/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 34/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 35/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 36/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0029 - val_loss: 9.9022e-04
# Epoch 37/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0029 - val_loss: 0.0066
# Epoch 38/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0109 - val_loss: 0.0140
# Epoch 39/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0061 - val_loss: 0.0044
# Epoch 40/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0096 - val_loss: 0.0033
# Epoch 41/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0042 - val_loss: 0.0081
# Epoch 42/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0085 - val_loss: 0.0055
# Epoch 43/50
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 44/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0050 - val_loss: 0.0010
# Epoch 45/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 46/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 47/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0034 - val_loss: 9.3178e-04
# Epoch 48/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0029 - val_loss: 9.2948e-04
# Epoch 49/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 50/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0029 - val_loss: 0.0040
# 3/3 [==============================] - 2s 7ms/step
# MSE: 0.003966018729916408
# Training with LSTM units=100, GRU units=100, dropout_rate=0.3, batch_size=64, epochs=100
# Epoch 1/100
# 5/5 [==============================] - 12s 569ms/step - loss: 0.1953 - val_loss: 0.0894
# Epoch 2/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0409 - val_loss: 0.0026
# Epoch 3/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0240 - val_loss: 0.0245
# Epoch 4/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0242 - val_loss: 0.0015
# Epoch 5/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0090 - val_loss: 0.0055
# Epoch 6/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0108 - val_loss: 0.0053
# Epoch 7/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0089 - val_loss: 0.0011
# Epoch 8/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0063 - val_loss: 0.0014
# Epoch 9/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0055 - val_loss: 0.0012
# Epoch 10/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 11/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 12/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 13/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 14/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 15/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 16/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 17/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 18/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 19/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 20/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 21/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 22/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 23/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 24/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 25/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 26/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 27/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 28/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 29/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 30/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 31/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 32/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 33/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 34/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 35/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 36/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 37/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 38/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 39/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 40/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 41/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 42/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 43/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 44/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 45/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 46/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 47/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 48/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0039 - val_loss: 9.6015e-04
# Epoch 49/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0027 - val_loss: 0.0052
# Epoch 50/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0051 - val_loss: 0.0029
# Epoch 51/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0029 - val_loss: 9.5984e-04
# Epoch 52/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 53/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0026 - val_loss: 9.3535e-04
# Epoch 54/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 55/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 56/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0025 - val_loss: 9.5467e-04
# Epoch 57/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 58/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0036 - val_loss: 0.0057
# Epoch 59/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0033 - val_loss: 9.6403e-04
# Epoch 60/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 61/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 62/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 9.2845e-04
# Epoch 63/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 64/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 65/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0027 - val_loss: 9.7523e-04
# Epoch 66/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 67/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 68/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 69/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 70/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 71/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 72/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 73/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 74/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0027 - val_loss: 8.5456e-04
# Epoch 75/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0034 - val_loss: 8.4766e-04
# Epoch 76/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 77/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 78/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 79/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 80/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 8.5748e-04
# Epoch 81/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 82/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 83/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 84/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 9.8910e-04
# Epoch 85/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 86/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 87/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 88/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 8.3290e-04
# Epoch 89/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 8.4661e-04
# Epoch 90/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 91/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 8.4424e-04
# Epoch 92/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 93/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 94/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 9.6634e-04
# Epoch 95/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 96/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 97/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 7.8924e-04
# Epoch 98/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 7.9955e-04
# Epoch 99/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 100/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0025 - val_loss: 0.0024
# 3/3 [==============================] - 1s 6ms/step
# MSE: 0.004289291903153032
# Best MSE: 0.003926330064845368 with params: {'lstm_units': 50, 'gru_units': 50, 'dropout_rate': 0.2, 'batch_size': 64, 'epochs': 50}
# 3/3 [==============================] - 0s 4ms/step

# %%
# Load your dataset (adjust the path to where your file is located)
data = pd.read_csv('../../data/Tdata.csv')

# Function to create dataset matrix for SVM
def create_dataset_svm(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), 0])  # Flatten to 1D array for SVM
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Preparing data for 'Avg_Usr'
feature = 'Avg_Usr'
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[[feature]])

# Split the data into training and test sets (80% train, 20% test)
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[:train_size], scaled_data[train_size:]

# SVM Model Prediction
look_back = 3
X_train_svm, y_train_svm = create_dataset_svm(train, look_back=look_back)
X_test_svm, y_test_svm = create_dataset_svm(test, look_back=look_back)

# Hyperparameter search for SVM units
best_mse_svm = float('inf')
best_svm_params = {}

# SVM hyperparameters to tune
svm_kernels = ['linear', 'rbf', 'poly']  # Different kernel functions
svm_C_values = [0.1, 1, 10]  # Regularization parameter (penalty)
svm_gamma_values = ['scale', 'auto']  # Kernel coefficient

for kernel in svm_kernels:
    for C in svm_C_values:
        for gamma in svm_gamma_values:
            print(f"Training SVM with kernel={kernel}, C={C}, gamma={gamma}")
            svm_model = SVR(kernel=kernel, C=C, gamma=gamma)
            svm_model.fit(X_train_svm, y_train_svm)

            # Predict and calculate MSE
            train_predict_svm = svm_model.predict(X_train_svm)
            test_predict_svm = svm_model.predict(X_test_svm)

            mse_svm = mean_squared_error(y_test_svm, test_predict_svm)
            print(f"MSE for SVM: {mse_svm}")

            if mse_svm < best_mse_svm:
                best_mse_svm = mse_svm
                best_svm_params = {'kernel': kernel, 'C': C, 'gamma': gamma}
                best_svm_model = svm_model

print(f'Best SVM params: {best_svm_params}, MSE: {best_mse_svm}')

# Prepare the data for LSTM/GRU hybrid using best SVM predictions
def create_dataset_hybrid(svm_predictions, original_data, look_back=1):
    X, Y = [], []
    for i in range(len(svm_predictions) - look_back):
        feature_set = np.hstack((original_data[i:(i + look_back)], svm_predictions[i:(i + look_back)].reshape(-1, 1)))
        X.append(feature_set)
        Y.append(original_data[i + look_back, 0])
    return np.array(X), np.array(Y)

# Create dataset for LSTM using SVM predictions
X_train_lstm, y_train_lstm = create_dataset_hybrid(train_predict_svm, train, look_back=look_back)
X_test_lstm, y_test_lstm = create_dataset_hybrid(test_predict_svm, test, look_back=look_back)

# Reshape input data for LSTM (samples, timesteps, features)
X_train_lstm = np.reshape(X_train_lstm, (X_train_lstm.shape[0], X_train_lstm.shape[1], 2))
X_test_lstm = np.reshape(X_test_lstm, (X_test_lstm.shape[0], X_test_lstm.shape[1], 2))

# Function to build and train LSTM and GRU models
def build_lstm_gru_model(input_shape, lstm_units, gru_units, dropout_rate):
    model = Sequential()
    model.add(LSTM(lstm_units, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(dropout_rate))
    model.add(GRU(gru_units, return_sequences=False))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Experiment with different LSTM, GRU units, and dropout rates
best_mse = float('inf')
best_params = {}
best_model = None

# Loop through different configurations
for lstm_units in [50, 100]:
    for gru_units in [50, 100, 150]:
        for dropout_rate in [0.2, 0.3]:
            for batch_size in [32, 64]:
                for epochs in [50, 100]:
                    print(f"Training LSTM-GRU with LSTM units={lstm_units}, GRU units={gru_units}, dropout_rate={dropout_rate}, batch_size={batch_size}, epochs={epochs}")
                    model = build_lstm_gru_model((look_back, 2), lstm_units, gru_units, dropout_rate)
                    model.fit(X_train_lstm, y_train_lstm, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=1)

                    # Predict
                    test_predict = model.predict(X_test_lstm)
                    
                    # Calculate MSE
                    mse = mean_squared_error(y_test_lstm, test_predict)
                    print(f'MSE: {mse}')

                    if mse < best_mse:
                        best_mse = mse
                        best_params = {'lstm_units': lstm_units, 'gru_units': gru_units, 'dropout_rate': dropout_rate, 'batch_size': batch_size, 'epochs': epochs}
                        best_model = model

print(f'Best MSE: {best_mse} with params: {best_params}')

# Predict with the best model
best_test_predict = best_model.predict(X_test_lstm)

# Invert predictions and actual values back to original scale
best_test_predict = scaler.inverse_transform(best_test_predict)
y_test_lstm = scaler.inverse_transform([y_test_lstm])

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_lstm[0], label='Actual', color='blue')
plt.plot(best_test_predict, label='Predicted', color='red')
plt.title(f'Actual vs Predicted for Avg_Usr using Stacked SVM-LSTM-GRU Model')
plt.xlabel('Time')
plt.ylabel('Avg_Usr')
plt.legend()
plt.show()
# Out:
# Training SVM with kernel=linear, C=0.1, gamma=scale
# MSE for SVM: 0.007014629818826911
# Training SVM with kernel=linear, C=0.1, gamma=auto
# MSE for SVM: 0.007014629818826911
# Training SVM with kernel=linear, C=1, gamma=scale
# MSE for SVM: 0.005632253323588096
# Training SVM with kernel=linear, C=1, gamma=auto
# MSE for SVM: 0.005632253323588096
# Training SVM with kernel=linear, C=10, gamma=scale
# MSE for SVM: 0.005565494518045634
# Training SVM with kernel=linear, C=10, gamma=auto
# MSE for SVM: 0.005565494518045634
# Training SVM with kernel=rbf, C=0.1, gamma=scale
# MSE for SVM: 0.009402962084865782
# Training SVM with kernel=rbf, C=0.1, gamma=auto
# MSE for SVM: 0.011126600625618318
# Training SVM with kernel=rbf, C=1, gamma=scale
# MSE for SVM: 0.008869347452998402
# Training SVM with kernel=rbf, C=1, gamma=auto
# MSE for SVM: 0.0067182374601026315
# Training SVM with kernel=rbf, C=10, gamma=scale
# MSE for SVM: 0.012707958067213561
# Training SVM with kernel=rbf, C=10, gamma=auto
# MSE for SVM: 0.005574595874541555
# Training SVM with kernel=poly, C=0.1, gamma=scale
# MSE for SVM: 0.04550698857571256
# Training SVM with kernel=poly, C=0.1, gamma=auto
# MSE for SVM: 0.0111915660234393
# Training SVM with kernel=poly, C=1, gamma=scale
# MSE for SVM: 0.04751519052753576
# Training SVM with kernel=poly, C=1, gamma=auto
# MSE for SVM: 0.029760012708265792
# Training SVM with kernel=poly, C=10, gamma=scale
# MSE for SVM: 0.04927520575649846
# Training SVM with kernel=poly, C=10, gamma=auto
# MSE for SVM: 0.038813262680641385
# Best SVM params: {'kernel': 'linear', 'C': 10, 'gamma': 'scale'}, MSE: 0.005565494518045634
# Training LSTM-GRU with LSTM units=50, GRU units=50, dropout_rate=0.2, batch_size=32, epochs=50
# Epoch 1/50
# 9/9 [==============================] - 13s 298ms/step - loss: 0.1862 - val_loss: 0.0941
# Epoch 2/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0373 - val_loss: 0.0012
# Epoch 3/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0228 - val_loss: 0.0018
# Epoch 4/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0153 - val_loss: 0.0059
# Epoch 5/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0125 - val_loss: 0.0041
# Epoch 6/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0100 - val_loss: 0.0014
# Epoch 7/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 0.0015
# Epoch 8/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 0.0045
# Epoch 9/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0058 - val_loss: 0.0018
# Epoch 10/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0020
# Epoch 11/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 0.0022
# Epoch 12/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 13/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 14/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 15/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 16/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 0.0020
# Epoch 17/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 18/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 19/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 20/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 21/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 22/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 23/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 24/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 25/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 26/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 27/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 28/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 29/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 30/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 31/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 32/50
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 33/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 34/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 35/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 36/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 37/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 38/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 39/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 40/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 41/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 42/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 43/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 44/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 45/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 46/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 47/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 48/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 49/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 50/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0017
# 3/3 [==============================] - 2s 5ms/step
# MSE: 0.005091617466200286
# Training LSTM-GRU with LSTM units=50, GRU units=50, dropout_rate=0.2, batch_size=32, epochs=100
# Epoch 1/100
# 9/9 [==============================] - 12s 213ms/step - loss: 0.1977 - val_loss: 0.1258
# Epoch 2/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0554 - val_loss: 0.0082
# Epoch 3/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0207 - val_loss: 0.0033
# Epoch 4/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0193 - val_loss: 0.0027
# Epoch 5/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0133 - val_loss: 0.0072
# Epoch 6/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0118 - val_loss: 0.0032
# Epoch 7/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0014
# Epoch 8/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 0.0030
# Epoch 9/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0017
# Epoch 10/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0017
# Epoch 11/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0019
# Epoch 12/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 13/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 14/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 15/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 16/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0020
# Epoch 17/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 18/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 0.0020
# Epoch 19/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 20/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 21/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 22/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 23/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 24/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 25/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 26/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 27/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 28/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 29/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 30/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 31/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 32/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 33/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 34/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 35/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0018
# Epoch 36/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 37/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 38/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 39/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 40/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 41/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 42/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 43/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 44/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 45/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 46/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 47/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 48/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 49/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 50/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 51/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 52/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 53/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 54/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 55/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 56/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 57/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 58/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 59/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 60/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 61/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 62/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 63/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 64/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 65/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 66/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 67/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 68/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 69/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 70/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 71/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 72/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 73/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 74/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 75/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 76/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 77/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 78/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 79/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 80/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 81/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 82/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 83/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 84/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 85/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 86/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 87/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 88/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 89/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 90/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 91/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 92/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 93/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 94/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 95/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 96/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 97/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 98/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 99/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 100/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0013
# 3/3 [==============================] - 1s 3ms/step
# MSE: 0.003535008929940906
# Training LSTM-GRU with LSTM units=50, GRU units=50, dropout_rate=0.2, batch_size=64, epochs=50
# Epoch 1/50
# 5/5 [==============================] - 13s 423ms/step - loss: 0.1923 - val_loss: 0.1668
# Epoch 2/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0956 - val_loss: 0.0582
# Epoch 3/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0329 - val_loss: 0.0033
# Epoch 4/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0198 - val_loss: 0.0068
# Epoch 5/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0293 - val_loss: 0.0031
# Epoch 6/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0186 - val_loss: 0.0030
# Epoch 7/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0149 - val_loss: 0.0112
# Epoch 8/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0162 - val_loss: 0.0095
# Epoch 9/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0128 - val_loss: 0.0046
# Epoch 10/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0110 - val_loss: 0.0014
# Epoch 11/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0119 - val_loss: 0.0013
# Epoch 12/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0098 - val_loss: 0.0019
# Epoch 13/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0077 - val_loss: 0.0042
# Epoch 14/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0078 - val_loss: 0.0059
# Epoch 15/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0075 - val_loss: 0.0041
# Epoch 16/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0016
# Epoch 17/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0014
# Epoch 18/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 19/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 20/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0051 - val_loss: 0.0023
# Epoch 21/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 22/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0023
# Epoch 23/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 24/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 25/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 26/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0016
# Epoch 27/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0028
# Epoch 28/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0027
# Epoch 29/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0023
# Epoch 30/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0028
# Epoch 31/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 32/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 33/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 34/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0033
# Epoch 35/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 36/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0031
# Epoch 37/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0057 - val_loss: 0.0020
# Epoch 38/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 39/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 40/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0058 - val_loss: 0.0024
# Epoch 41/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 42/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 43/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0041 - val_loss: 0.0025
# Epoch 44/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 45/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 46/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 47/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 48/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 49/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 50/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0041 - val_loss: 0.0019
# 3/3 [==============================] - 2s 4ms/step
# MSE: 0.008022087162714122
# Training LSTM-GRU with LSTM units=50, GRU units=50, dropout_rate=0.2, batch_size=64, epochs=100
# Epoch 1/100
# 5/5 [==============================] - 12s 435ms/step - loss: 0.2048 - val_loss: 0.1793
# Epoch 2/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1033 - val_loss: 0.0700
# Epoch 3/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0389 - val_loss: 0.0068
# Epoch 4/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0190 - val_loss: 0.0046
# Epoch 5/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0279 - val_loss: 0.0036
# Epoch 6/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0207 - val_loss: 0.0019
# Epoch 7/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0142 - val_loss: 0.0094
# Epoch 8/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0150 - val_loss: 0.0109
# Epoch 9/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0141 - val_loss: 0.0054
# Epoch 10/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0104 - val_loss: 0.0013
# Epoch 11/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0108 - val_loss: 0.0018
# Epoch 12/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0107 - val_loss: 0.0014
# Epoch 13/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0078 - val_loss: 0.0033
# Epoch 14/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0076 - val_loss: 0.0054
# Epoch 15/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0072 - val_loss: 0.0049
# Epoch 16/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 17/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 18/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 19/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0016
# Epoch 20/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 21/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 22/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 23/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 24/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0047 - val_loss: 0.0022
# Epoch 25/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 26/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0044 - val_loss: 0.0026
# Epoch 27/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0042 - val_loss: 0.0020
# Epoch 28/100
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 29/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 30/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 31/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0050 - val_loss: 0.0022
# Epoch 32/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 33/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 34/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0088 - val_loss: 0.0159
# Epoch 35/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0113 - val_loss: 0.0029
# Epoch 36/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 37/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0069 - val_loss: 0.0018
# Epoch 38/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 39/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0057 - val_loss: 0.0033
# Epoch 40/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 41/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0045 - val_loss: 0.0023
# Epoch 42/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 43/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 44/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0042 - val_loss: 0.0022
# Epoch 45/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 46/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 47/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0041 - val_loss: 0.0019
# Epoch 48/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 49/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 50/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 51/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 52/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 53/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 54/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 55/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 56/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 57/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 58/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 59/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 60/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 61/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 62/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 63/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 64/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 65/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 66/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0051 - val_loss: 0.0017
# Epoch 67/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 68/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0041 - val_loss: 0.0019
# Epoch 69/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 70/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 71/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 72/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 73/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 74/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 75/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 76/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 77/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 78/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 79/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 80/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 81/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 82/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 83/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 84/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 85/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 86/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 87/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 88/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 89/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 90/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 91/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 92/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 93/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 94/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 95/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 96/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 97/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 98/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 99/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 100/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0050 - val_loss: 0.0021
# 3/3 [==============================] - 1s 4ms/step
# MSE: 0.006634534013734813
# Training LSTM-GRU with LSTM units=50, GRU units=50, dropout_rate=0.3, batch_size=32, epochs=50
# Epoch 1/50
# 9/9 [==============================] - 13s 306ms/step - loss: 0.1774 - val_loss: 0.0791
# Epoch 2/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0332 - val_loss: 0.0032
# Epoch 3/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0314 - val_loss: 0.0024
# Epoch 4/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0162 - val_loss: 0.0093
# Epoch 5/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0146 - val_loss: 0.0054
# Epoch 6/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0111 - val_loss: 0.0013
# Epoch 7/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0038
# Epoch 8/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 0.0032
# Epoch 9/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0059 - val_loss: 0.0016
# Epoch 10/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0027
# Epoch 11/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 12/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 13/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 14/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0053 - val_loss: 0.0023
# Epoch 15/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0048 - val_loss: 0.0027
# Epoch 16/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0073 - val_loss: 0.0056
# Epoch 17/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0059 - val_loss: 0.0018
# Epoch 18/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.0030
# Epoch 19/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 20/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 21/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 22/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 23/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 24/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 25/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 26/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 27/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0043 - val_loss: 0.0020
# Epoch 28/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 29/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 30/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0019
# Epoch 31/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 32/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 33/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 34/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 35/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 36/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 38/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 39/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 40/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 41/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 42/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0020
# Epoch 43/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0025
# Epoch 44/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0020
# Epoch 45/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 46/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 47/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 48/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 49/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 50/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0018
# 3/3 [==============================] - 1s 4ms/step
# MSE: 0.004828645003879457
# Training LSTM-GRU with LSTM units=50, GRU units=50, dropout_rate=0.3, batch_size=32, epochs=100
# Epoch 1/100
# 9/9 [==============================] - 12s 172ms/step - loss: 0.1755 - val_loss: 0.0885
# Epoch 2/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0356 - val_loss: 0.0016
# Epoch 3/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0292 - val_loss: 0.0017
# Epoch 4/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0178 - val_loss: 0.0099
# Epoch 5/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0163 - val_loss: 0.0079
# Epoch 6/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0126 - val_loss: 0.0017
# Epoch 7/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0109 - val_loss: 0.0025
# Epoch 8/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0087 - val_loss: 0.0038
# Epoch 9/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0070 - val_loss: 0.0016
# Epoch 10/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0019
# Epoch 11/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0060 - val_loss: 0.0026
# Epoch 12/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0055 - val_loss: 0.0026
# Epoch 13/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 14/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 15/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 16/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0024
# Epoch 17/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0019
# Epoch 18/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 19/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 20/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 21/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 22/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 23/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0045 - val_loss: 0.0020
# Epoch 24/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 25/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0018
# Epoch 26/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0041 - val_loss: 0.0019
# Epoch 27/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 28/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 29/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 30/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 31/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 32/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 33/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 34/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 35/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 36/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 37/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 38/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 39/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 40/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 41/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 42/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 43/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 44/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 45/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0075 - val_loss: 0.0017
# Epoch 46/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0024
# Epoch 47/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 48/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 49/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 50/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 51/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 52/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 53/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 54/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 55/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 56/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 57/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 58/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 59/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 60/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 61/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 62/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 63/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 64/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 65/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 66/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 67/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 68/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 69/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 70/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 71/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 72/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 73/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 74/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 75/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 76/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 77/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 78/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 79/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 80/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 81/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 82/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 83/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 84/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0031 - val_loss: 0.0014
# Epoch 85/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 86/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 87/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 88/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 89/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0031 - val_loss: 0.0014
# Epoch 90/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 91/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 92/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 93/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 94/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 95/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 96/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 97/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 98/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 99/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 100/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0014
# 3/3 [==============================] - 1s 3ms/step
# MSE: 0.0036160306238696292
# Training LSTM-GRU with LSTM units=50, GRU units=50, dropout_rate=0.3, batch_size=64, epochs=50
# Epoch 1/50
# 5/5 [==============================] - 13s 529ms/step - loss: 0.2151 - val_loss: 0.1830
# Epoch 2/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1070 - val_loss: 0.0695
# Epoch 3/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0397 - val_loss: 0.0096
# Epoch 4/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0185 - val_loss: 0.0033
# Epoch 5/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0274 - val_loss: 0.0036
# Epoch 6/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0195 - val_loss: 0.0025
# Epoch 7/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0144 - val_loss: 0.0090
# Epoch 8/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0144 - val_loss: 0.0079
# Epoch 9/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0123 - val_loss: 0.0038
# Epoch 10/50
# ...
# Epoch 95/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 96/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 97/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 98/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 99/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 100/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0012
# 3/3 [==============================] - 1s 4ms/step
# MSE: 0.0034861376970979742
# Training LSTM-GRU with LSTM units=100, GRU units=150, dropout_rate=0.3, batch_size=64, epochs=50
# Epoch 1/50
# 5/5 [==============================] - 12s 366ms/step - loss: 0.1684 - val_loss: 0.0553
# Epoch 2/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0217 - val_loss: 0.0164
# Epoch 3/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0377 - val_loss: 0.0042
# Epoch 4/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0136 - val_loss: 0.0114
# Epoch 5/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0158 - val_loss: 0.0143
# Epoch 6/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0119 - val_loss: 0.0020
# Epoch 7/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0082 - val_loss: 0.0014
# Epoch 8/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0077 - val_loss: 0.0021
# Epoch 9/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 10/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0065 - val_loss: 0.0022
# Epoch 11/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 12/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0048 - val_loss: 0.0016
# Epoch 13/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0041 - val_loss: 0.0022
# Epoch 14/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0043 - val_loss: 0.0020
# Epoch 15/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 16/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 17/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 18/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0040 - val_loss: 0.0023
# Epoch 19/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0044 - val_loss: 0.0023
# Epoch 20/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 21/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 22/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 23/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 24/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0046 - val_loss: 0.0027
# Epoch 25/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0041 - val_loss: 0.0019
# Epoch 26/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0042 - val_loss: 0.0023
# Epoch 27/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 28/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 29/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 30/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 31/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 32/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0041 - val_loss: 0.0034
# Epoch 33/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0043 - val_loss: 0.0020
# Epoch 34/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 35/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 36/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 37/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0043 - val_loss: 0.0024
# Epoch 38/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 39/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 40/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0066 - val_loss: 0.0075
# Epoch 41/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0057 - val_loss: 0.0032
# Epoch 42/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0069 - val_loss: 0.0027
# Epoch 43/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0043 - val_loss: 0.0032
# Epoch 44/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 45/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0052 - val_loss: 0.0022
# Epoch 46/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0047 - val_loss: 0.0054
# Epoch 47/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0053 - val_loss: 0.0027
# Epoch 48/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 49/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 50/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0043 - val_loss: 0.0018
# 3/3 [==============================] - 2s 6ms/step
# MSE: 0.004657017258148933
# Training LSTM-GRU with LSTM units=100, GRU units=150, dropout_rate=0.3, batch_size=64, epochs=100
# Epoch 1/100
# 5/5 [==============================] - 12s 574ms/step - loss: 0.1781 - val_loss: 0.0666
# Epoch 2/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0292 - val_loss: 0.0072
# Epoch 3/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0291 - val_loss: 0.0021
# Epoch 4/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0132 - val_loss: 0.0158
# Epoch 5/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0185 - val_loss: 0.0193
# Epoch 6/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0131 - val_loss: 0.0017
# Epoch 7/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0094 - val_loss: 0.0022
# Epoch 8/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0086 - val_loss: 0.0030
# Epoch 9/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 10/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0086 - val_loss: 0.0047
# Epoch 11/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 12/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 13/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 14/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 15/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 16/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 17/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0056 - val_loss: 0.0022
# Epoch 18/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 19/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 20/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0054 - val_loss: 0.0027
# Epoch 21/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 22/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 23/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 24/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 25/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 26/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 27/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 28/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 29/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 30/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 31/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 32/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0041 - val_loss: 0.0019
# Epoch 33/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 34/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 35/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0040 - val_loss: 0.0024
# Epoch 36/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0040 - val_loss: 0.0020
# Epoch 37/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 38/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0041 - val_loss: 0.0026
# Epoch 39/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 40/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 41/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 42/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 43/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 44/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 45/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 46/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 47/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 48/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 49/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0040 - val_loss: 0.0024
# Epoch 50/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 51/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 52/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 53/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 54/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 55/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 56/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 57/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 58/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 59/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0040 - val_loss: 0.0024
# Epoch 60/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 61/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0042 - val_loss: 0.0023
# Epoch 62/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 63/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 64/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 65/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 66/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 67/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 68/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 69/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 70/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 71/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 72/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 73/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 74/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 75/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 76/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 77/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 78/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 79/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 80/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 81/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 82/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0050 - val_loss: 0.0062
# Epoch 83/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0045 - val_loss: 0.0029
# Epoch 84/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0050 - val_loss: 0.0020
# Epoch 85/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0067 - val_loss: 0.0092
# Epoch 86/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0054 - val_loss: 0.0028
# Epoch 87/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 88/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 89/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 90/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 91/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 92/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 93/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 94/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 95/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 96/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 97/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 98/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 99/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 100/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0039 - val_loss: 0.0017
# 3/3 [==============================] - 2s 6ms/step
# MSE: 0.0041529890730742
# Best MSE: 0.0033312805183702515 with params: {'lstm_units': 100, 'gru_units': 150, 'dropout_rate': 0.2, 'batch_size': 32, 'epochs': 100}
# 3/3 [==============================] - 0s 6ms/step
