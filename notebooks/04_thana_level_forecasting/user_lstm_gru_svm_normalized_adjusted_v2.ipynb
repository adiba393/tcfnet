# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Load your dataset (adjust the path to where your file is located)
data = pd.read_csv('../../data/Tdata.csv')

# %%
data
# Out:
#           Date   Avg_Usr  Avg_Usr_TP_DL  Avg_Usr_TP_UL       CSSR  \
# 0     1-Sep-22  16209.61       3.446027       0.564643  98.698393
# 1     2-Sep-22  16003.68       3.250536       0.582187  98.690223
# 2     3-Sep-22  16058.39       3.597009       0.609911  98.715045
# 3     4-Sep-22  16390.15       3.726696       0.561250  98.599777
# 4     5-Sep-22  16051.58       3.726473       0.537813  98.653527
# ..         ...       ...            ...            ...        ...
# 361  28-Aug-23  23298.68       7.064972       0.477116  99.415142
# 362  29-Aug-23  24511.92       6.966452       0.490361  99.463776
# 363  30-Aug-23  24467.48       6.898596       0.493188  99.626964
# 364  31-Aug-23  23803.97       7.090190       0.510664  99.661120
# 365   1-Sep-23  23264.06       7.206679       0.558558  99.655806
#
#      DL_256QAM_PROPORTION  DL_LATENCY  DL_PACK_LOSS_RATE  DL_QPSK_PROPORTION  \
# 0                0.745357   11.741116           0.101875           36.163527
# 1                0.700536   11.614241           0.115580           35.475402
# 2                0.739732   11.503259           0.096250           35.623393
# 3                0.746696   11.807366           0.110536           35.997411
# 4                0.751071   11.534911           0.111250           35.609866
# ..                    ...         ...                ...                 ...
# 361              0.773226    7.505920           0.078786           38.537059
# 362              0.727324    7.704269           0.097002           38.737799
# 363              0.754516    7.891157           0.096129           38.392467
# 364              0.809222    7.563378           0.088520           38.284099
# 365              0.750019    7.531954           0.088008           38.537457
#
#      DL_TRAFFIC_MB  Max_Usr  S1_SIG_SUCC  TOTAL_DOWNTIME      Traffic  \
# 0      28748026.10    32848  251968.1429      393.651786  32890183.17
# 1      29619777.66    32313  243918.5625      389.156250  34033315.47
# 2      29102851.45    32565  246798.6027      388.062500  33383868.74
# 3      28466880.25    33303  257327.6563      387.245536  32606986.82
# 4      28558733.04    32314  256012.4866      390.343750  32652591.96
# ..             ...      ...          ...             ...          ...
# 361    56768939.70    58629  127670.3321     1092.662239  63974723.71
# 362    57456743.34    54688  129612.0247     1074.193548  64944563.74
# 363    58389814.53    56111  133872.1556      362.741936  65854384.38
# 364    59759544.72    51682  134106.0171        0.000000  67421649.20
# 365    59760454.24    51146  127557.1765       11.464896  67634282.38
#
#      UL_QPSK_PROPORTION  UL_TRAFFIC_MB
# 0             37.050402     4142157.11
# 1             38.724911     4413537.60
# 2             36.708884     4281017.27
# 3             36.628527     4140106.66
# 4             37.344955     4093859.29
# ..                  ...            ...
# 361           42.272201     7205784.11
# 362           40.884345     7487820.29
# 363           40.078159     7464569.80
# 364           39.138444     7662104.58
# 365           39.083150     7873828.23
#
# [366 rows x 16 columns]

# %%
# Features to be used for prediction
features = ['Max_Usr', 'Avg_Usr']

# Normalize the data for selected features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[features])

# Split the data into training and test sets (80% train, 20% test)
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[:train_size], scaled_data[train_size:]

# Function to create dataset matrix for SVM
def create_dataset_svm(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), :-1].flatten())  # Flatten the look_back timesteps
        Y.append(dataset[i + look_back, -1])  # Use the target feature (last column)
    return np.array(X), np.array(Y)

# Create dataset for SVM (look_back=3)
look_back = 3
X_train, y_train = create_dataset_svm(train, look_back=look_back)
X_test, y_test = create_dataset_svm(test, look_back=look_back)

# Train SVM model with different hyperparameters
best_mse = float('inf')
best_params = {}
best_model = None

# Hyperparameter tuning loop for SVM
for kernel in ['linear', 'rbf', 'poly']:
    for C in [0.1, 1, 10]:
        for gamma in ['scale', 'auto']:
            print(f'Training with kernel={kernel}, C={C}, gamma={gamma}')
            svm_model = SVR(kernel=kernel, C=C, gamma=gamma)
            svm_model.fit(X_train, y_train)
            
            # Predict and calculate MSE
            test_predict = svm_model.predict(X_test)
            mse = mean_squared_error(y_test, test_predict)
            print(f'MSE (normalized): {mse}')
            
            # Track the best model
            if mse < best_mse:
                best_mse = mse
                best_params = {'kernel': kernel, 'C': C, 'gamma': gamma}
                best_model = svm_model

print(f'Best MSE (normalized): {best_mse} with params: {best_params}')

# Predict with the best model
best_test_predict = best_model.predict(X_test)

# Plot the best model's predictions with actual values
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual (Normalized)', color='blue')
plt.plot(best_test_predict, label='Predicted (Normalized)', color='red')
plt.title(f'Normalized Actual vs Predicted for {features[-1]} using SVM')
plt.xlabel('Time')
plt.ylabel(f'Normalized {features[-1]}')
plt.legend()
plt.show()
# Out:
# Training with kernel=linear, C=0.1, gamma=scale
# MSE (normalized): 0.029477734018670133
# Training with kernel=linear, C=0.1, gamma=auto
# MSE (normalized): 0.029477734018670133
# Training with kernel=linear, C=1, gamma=scale
# MSE (normalized): 0.04118940030667041
# Training with kernel=linear, C=1, gamma=auto
# MSE (normalized): 0.04118940030667041
# Training with kernel=linear, C=10, gamma=scale
# MSE (normalized): 0.04228516805524474
# Training with kernel=linear, C=10, gamma=auto
# MSE (normalized): 0.04228516805524474
# Training with kernel=rbf, C=0.1, gamma=scale
# MSE (normalized): 0.05941096810934791
# Training with kernel=rbf, C=0.1, gamma=auto
# MSE (normalized): 0.01135313534145348
# Training with kernel=rbf, C=1, gamma=scale
# MSE (normalized): 0.07078192562553154
# Training with kernel=rbf, C=1, gamma=auto
# MSE (normalized): 0.008339563539787122
# Training with kernel=rbf, C=10, gamma=scale
# MSE (normalized): 0.04814150477373856
# Training with kernel=rbf, C=10, gamma=auto
# MSE (normalized): 0.008870178374209689
# Training with kernel=poly, C=0.1, gamma=scale
# MSE (normalized): 0.7274750369537495
# Training with kernel=poly, C=0.1, gamma=auto
# MSE (normalized): 0.025541369252982588
# Training with kernel=poly, C=1, gamma=scale
# MSE (normalized): 0.7304771496504794
# Training with kernel=poly, C=1, gamma=auto
# MSE (normalized): 0.4280725393562818
# Training with kernel=poly, C=10, gamma=scale
# MSE (normalized): 0.7131254018872024
# Training with kernel=poly, C=10, gamma=auto
# MSE (normalized): 0.5713936342293346
# Best MSE (normalized): 0.008339563539787122 with params: {'kernel': 'rbf', 'C': 1, 'gamma': 'auto'}

# %%
# Function to create dataset matrix for SVM
def create_dataset_svm(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), 0])  # Flatten to a 1D array for SVM
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Preparing data for 'Avg_Usr'
feature = 'Avg_Usr'

# Normalize the 'Avg_Usr' data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[[feature]])

# Split the data into training and test sets (80% train, 20% test)
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[:train_size], scaled_data[train_size:]

# Create dataset for SVM (look_back=3)
look_back = 3
X_train, y_train = create_dataset_svm(train, look_back=look_back)
X_test, y_test = create_dataset_svm(test, look_back=look_back)

# Train SVM model with different hyperparameters
best_mse = float('inf')
best_params = {}
best_model = None

# Hyperparameter tuning loop for SVM
for kernel in ['linear', 'rbf', 'poly']:
    for C in [0.1, 1, 10]:
        for gamma in ['scale', 'auto']:
            print(f'Training with kernel={kernel}, C={C}, gamma={gamma}')
            svm_model = SVR(kernel=kernel, C=C, gamma=gamma)
            svm_model.fit(X_train, y_train)
            
            # Predict and calculate MSE
            test_predict = svm_model.predict(X_test)
            mse = mean_squared_error(y_test, test_predict)
            print(f'MSE (normalized): {mse}')
            
            # Track the best model
            if mse < best_mse:
                best_mse = mse
                best_params = {'kernel': kernel, 'C': C, 'gamma': gamma}
                best_model = svm_model

print(f'Best MSE (normalized): {best_mse} with params: {best_params}')

# Predict with the best model
best_test_predict = best_model.predict(X_test)

# Plot the best model's predictions with actual values
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual (Normalized)', color='blue')
plt.plot(best_test_predict, label='Predicted (Normalized)', color='red')
plt.title(f'Normalized Actual vs Predicted for {feature} using SVM')
plt.xlabel('Time')
plt.ylabel(f'Normalized {feature}')
plt.legend()
plt.show()
# Out:
# Training with kernel=linear, C=0.1, gamma=scale
# MSE (normalized): 0.007014629818826911
# Training with kernel=linear, C=0.1, gamma=auto
# MSE (normalized): 0.007014629818826911
# Training with kernel=linear, C=1, gamma=scale
# MSE (normalized): 0.005632253323588096
# Training with kernel=linear, C=1, gamma=auto
# MSE (normalized): 0.005632253323588096
# Training with kernel=linear, C=10, gamma=scale
# MSE (normalized): 0.005565494518045634
# Training with kernel=linear, C=10, gamma=auto
# MSE (normalized): 0.005565494518045634
# Training with kernel=rbf, C=0.1, gamma=scale
# MSE (normalized): 0.009402962084865782
# Training with kernel=rbf, C=0.1, gamma=auto
# MSE (normalized): 0.011126600625618318
# Training with kernel=rbf, C=1, gamma=scale
# MSE (normalized): 0.008869347452998402
# Training with kernel=rbf, C=1, gamma=auto
# MSE (normalized): 0.0067182374601026315
# Training with kernel=rbf, C=10, gamma=scale
# MSE (normalized): 0.012707958067213561
# Training with kernel=rbf, C=10, gamma=auto
# MSE (normalized): 0.005574595874541555
# Training with kernel=poly, C=0.1, gamma=scale
# MSE (normalized): 0.04550698857571256
# Training with kernel=poly, C=0.1, gamma=auto
# MSE (normalized): 0.0111915660234393
# Training with kernel=poly, C=1, gamma=scale
# MSE (normalized): 0.04751519052753576
# Training with kernel=poly, C=1, gamma=auto
# MSE (normalized): 0.029760012708265792
# Training with kernel=poly, C=10, gamma=scale
# MSE (normalized): 0.04927520575649846
# Training with kernel=poly, C=10, gamma=auto
# MSE (normalized): 0.038813262680641385
# Best MSE (normalized): 0.005565494518045634 with params: {'kernel': 'linear', 'C': 10, 'gamma': 'scale'}

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
import matplotlib.pyplot as plt

# %%
# Load your dataset (adjust the path to where your file is located)
data = pd.read_csv('../../data/Tdata.csv')

# Function to create dataset matrix for SVM
def create_dataset_svm(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), 0])  # Flatten to 1D array for SVM
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Preparing data for 'Avg_Usr'
feature = 'Avg_Usr'
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[[feature]])

# Split the data into training and test sets (80% train, 20% test)
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[:train_size], scaled_data[train_size:]

# Create dataset for SVM (look_back=3)
look_back = 3
X_train_svm, y_train_svm = create_dataset_svm(train, look_back=look_back)
X_test_svm, y_test_svm = create_dataset_svm(test, look_back=look_back)

# Train SVM model (best hyperparameters from tuning)
svm_model = SVR(kernel='rbf', C=1, gamma='scale')
svm_model.fit(X_train_svm, y_train_svm)

# Predict with SVM model
train_predict_svm = svm_model.predict(X_train_svm)
test_predict_svm = svm_model.predict(X_test_svm)

# Prepare the data for GRU model
def create_dataset_gru(svm_predictions, original_data, look_back=1):
    X, Y = [], []
    for i in range(len(svm_predictions) - look_back):
        # Combine original time series data and SVM predictions as features
        feature_set = np.hstack((original_data[i:(i + look_back)], svm_predictions[i:(i + look_back)].reshape(-1, 1)))
        X.append(feature_set)
        Y.append(original_data[i + look_back, 0])
    return np.array(X), np.array(Y)

# Creating datasets for GRU
X_train_gru, y_train_gru = create_dataset_gru(train_predict_svm, train, look_back=look_back)
X_test_gru, y_test_gru = create_dataset_gru(test_predict_svm, test, look_back=look_back)

# Reshape input data to 3D (samples, timesteps, features) for GRU input
X_train_gru = np.reshape(X_train_gru, (X_train_gru.shape[0], X_train_gru.shape[1], 2))  # Two features: original and SVM
X_test_gru = np.reshape(X_test_gru, (X_test_gru.shape[0], X_test_gru.shape[1], 2))

# Define and train the GRU model
def build_gru_model(input_shape):
    model = Sequential()
    model.add(GRU(100, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(GRU(50, return_sequences=False))
    model.add(Dense(1))  # Output layer for regression

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Build and train GRU model
gru_model = build_gru_model((look_back, 2))
gru_model.fit(X_train_gru, y_train_gru, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# Predict with the GRU model
train_predict_gru = gru_model.predict(X_train_gru)
test_predict_gru = gru_model.predict(X_test_gru)

# Invert predictions and actual values back to original scale
train_predict_gru = scaler.inverse_transform(train_predict_gru)
test_predict_gru = scaler.inverse_transform(test_predict_gru)
y_train_gru = scaler.inverse_transform([y_train_gru])
y_test_gru = scaler.inverse_transform([y_test_gru])

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_gru[0], label='Actual', color='blue')
plt.plot(test_predict_gru, label='Predicted', color='red')
plt.title('Actual vs Predicted for Avg_Usr using Stacked SVM-GRU Model')
plt.xlabel('Time')
plt.ylabel('Avg_Usr')
plt.legend()
plt.show()

# Calculate MSE for the hybrid model
mse_gru = mean_squared_error(y_test_gru[0], test_predict_gru)
print(f'Hybrid Model MSE: {mse_gru}')
# Out:
# Epoch 1/50
# 9/9 [==============================] - 7s 179ms/step - loss: 0.0591 - val_loss: 0.0353
# Epoch 2/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0217 - val_loss: 0.0062
# Epoch 3/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0138 - val_loss: 0.0044
# Epoch 4/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 5/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 6/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 0.0013
# Epoch 7/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 8/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 9/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 10/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 11/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 12/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 13/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 9.8498e-04
# Epoch 14/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 15/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 9.4267e-04
# Epoch 16/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 17/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 18/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 19/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0024 - val_loss: 9.1460e-04
# Epoch 20/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 21/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 8.5356e-04
# Epoch 22/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 23/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 24/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 8.8473e-04
# Epoch 25/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 26/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 7.6159e-04
# Epoch 27/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 7.8744e-04
# Epoch 28/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 29/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 7.6816e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 31/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 32/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 33/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 8.0096e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 35/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0022 - val_loss: 8.9950e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 7.9603e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 38/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 8.0533e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 40/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 41/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 9.4975e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 9.3820e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 6.2160e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 45/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 6.5107e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 47/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 48/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 6.1541e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 50/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 6.5468e-04
# 9/9 [==============================] - 1s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# Hybrid Model MSE: 1126111.0417626072
