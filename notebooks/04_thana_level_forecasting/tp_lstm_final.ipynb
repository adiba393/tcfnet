# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
# Load the dataset
data = pd.read_csv("../../data/Test Data.csv")

# %%
# Convert 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], format='%d-%b-%y')

# %%
data.set_index('Date', inplace=True)

# %%
# Group by 'Date' and calculate the average for each column
data_avg = data.groupby('Date').mean()

# %%
data_avg
# Out:
#             User Count Average  Average User Throughput DL  \
# Date
# 2022-09-01            16209.61                    3.446027
# 2022-09-02            16003.68                    3.250536
# 2022-09-03            16058.39                    3.597009
# 2022-09-04            16390.15                    3.726696
# 2022-09-05            16051.58                    3.726473
# ...                        ...                         ...
# 2023-08-28            23298.68                    7.064972
# 2023-08-29            24511.92                    6.966452
# 2023-08-30            24467.48                    6.898596
# 2023-08-31            23803.97                    7.090190
# 2023-09-01            23264.06                    7.206679
#
#             Average User Throughput UL       CSSR  DL_256QAM_PROPORTION  \
# Date
# 2022-09-01                    0.564643  98.698393              0.745357
# 2022-09-02                    0.582187  98.690223              0.700536
# 2022-09-03                    0.609911  98.715045              0.739732
# 2022-09-04                    0.561250  98.599777              0.746696
# 2022-09-05                    0.537813  98.653527              0.751071
# ...                                ...        ...                   ...
# 2023-08-28                    0.477116  99.415142              0.773226
# 2023-08-29                    0.490361  99.463776              0.727324
# 2023-08-30                    0.493188  99.626964              0.754516
# 2023-08-31                    0.510664  99.661120              0.809222
# 2023-09-01                    0.558558  99.655806              0.750019
#
#             DL_LATENCY  DL_PACK_LOSS_RATE  DL_QPSK_PROPORTION  Data Volume DL  \
# Date
# 2022-09-01   11.741116           0.101875           36.163527     28748026.10
# 2022-09-02   11.614241           0.115580           35.475402     29619777.66
# 2022-09-03   11.503259           0.096250           35.623393     29102851.45
# 2022-09-04   11.807366           0.110536           35.997411     28466880.25
# 2022-09-05   11.534911           0.111250           35.609866     28558733.04
# ...                ...                ...                 ...             ...
# 2023-08-28    7.505920           0.078786           38.537059     56768939.70
# 2023-08-29    7.704269           0.097002           38.737799     57456743.34
# 2023-08-30    7.891157           0.096129           38.392467     58389814.53
# 2023-08-31    7.563378           0.088520           38.284099     59759544.72
# 2023-09-01    7.531954           0.088008           38.537457     59760454.24
#
#             User Count Maximum  S1_SIG_SUCC  TOTAL_DOWNTIME      Traffic  \
# Date
# 2022-09-01             32848.0  251968.1429      393.651786  32890183.17
# 2022-09-02             32313.0  243918.5625      389.156250  34033315.47
# 2022-09-03             32565.0  246798.6027      388.062500  33383868.74
# 2022-09-04             33303.0  257327.6563      387.245536  32606986.82
# 2022-09-05             32314.0  256012.4866      390.343750  32652591.96
# ...                        ...          ...             ...          ...
# 2023-08-28             58629.0  127670.3321     1092.662239  63974723.71
# 2023-08-29             54688.0  129612.0247     1074.193548  64944563.74
# 2023-08-30             56111.0  133872.1556      362.741936  65854384.38
# 2023-08-31             51682.0  134106.0171        0.000000  67421649.20
# 2023-09-01             51146.0  127557.1765       11.464896  67634282.38
#
#             UL_QPSK_PROPORTION  UL_TRAFFIC_MB
# Date
# 2022-09-01           37.050402     4142157.11
# 2022-09-02           38.724911     4413537.60
# 2022-09-03           36.708884     4281017.27
# 2022-09-04           36.628527     4140106.66
# 2022-09-05           37.344955     4093859.29
# ...                        ...            ...
# 2023-08-28           42.272201     7205784.11
# 2023-08-29           40.884345     7487820.29
# 2023-08-30           40.078159     7464569.80
# 2023-08-31           39.138444     7662104.58
# 2023-09-01           39.083150     7873828.23
#
# [366 rows x 15 columns]

# %%
# Select the columns for modeling
variables = data_avg[['User Count Average', 'Traffic', 'Average User Throughput DL']]

# Normalize the data to the range [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(variables)

# Convert the scaled data back to a DataFrame
scaled_data = pd.DataFrame(scaled_data, columns=variables.columns, index=variables.index)

# Create sequences of data for LSTM (e.g., using 10 previous timesteps to predict the next one)
def create_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length, -1])  # Predicting 'Average User Throughput DL'
    return np.array(X), np.array(y)

seq_length = 10
X, y = create_sequences(scaled_data.values, seq_length)

# Split the data into training and testing sets
train_size = int(X.shape[0] * 0.7)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape input to be [samples, time steps, features] for LSTM
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))  # Predicting one output (Average User Throughput DL)

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2)

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform the predictions and actual values
y_train_inv = scaler.inverse_transform(np.concatenate([X_train[:, -1, :-1], train_predict], axis=1))[:, -1]
y_test_inv = scaler.inverse_transform(np.concatenate([X_test[:, -1, :-1], test_predict], axis=1))[:, -1]
y_train_actual = scaler.inverse_transform(np.concatenate([X_train[:, -1, :-1], y_train.reshape(-1, 1)], axis=1))[:, -1]
y_test_actual = scaler.inverse_transform(np.concatenate([X_test[:, -1, :-1], y_test.reshape(-1, 1)], axis=1))[:, -1]

# Evaluate the model
mse_train = mean_squared_error(y_train_actual, y_train_inv)
mse_test = mean_squared_error(y_test_actual, y_test_inv)
# Out:
# Epoch 1/40
# 7/7 [==============================] - 8s 279ms/step - loss: 0.0045 - val_loss: 0.0061
# Epoch 2/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0064
# Epoch 3/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0088
# Epoch 4/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 0.0061
# Epoch 5/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0071
# Epoch 6/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0027 - val_loss: 0.0064
# Epoch 7/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0072
# Epoch 8/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 0.0064
# Epoch 9/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0070
# Epoch 10/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0091
# Epoch 11/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0057
# Epoch 12/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0027 - val_loss: 0.0075
# Epoch 13/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0063
# Epoch 14/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0068
# Epoch 15/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0068
# Epoch 16/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0056
# Epoch 17/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0056
# Epoch 18/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0073
# Epoch 19/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0055
# Epoch 20/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0023 - val_loss: 0.0070
# Epoch 21/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0068
# Epoch 22/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0078
# Epoch 23/40
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0057
# Epoch 24/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0052
# Epoch 25/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 0.0080
# Epoch 26/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0083
# Epoch 27/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0052
# Epoch 28/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0023 - val_loss: 0.0059
# Epoch 29/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0063
# Epoch 30/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0053
# Epoch 31/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0022 - val_loss: 0.0052
# Epoch 32/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0071
# Epoch 33/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0052
# Epoch 34/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0051
# Epoch 35/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 36/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0068
# Epoch 37/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0050
# Epoch 38/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0049
# Epoch 39/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0027 - val_loss: 0.0086
# Epoch 40/40
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0049
# 8/8 [==============================] - 1s 7ms/step
# 4/4 [==============================] - 0s 5ms/step

# %%
# Plot the results for testing data
plt.figure(figsize=(12, 6))
plt.plot(variables.index[train_size + seq_length:], y_test_actual, label='Actual Average User Throughput DL')
plt.plot(variables.index[train_size + seq_length:], y_test_inv, label='Predicted Average User Throughput DL', color='red')
plt.title(f'LSTM Model - DL Throughput Prediction (Test MSE: {mse_test:.3f})')
plt.xlabel('Date')
plt.ylabel('Throughput')
plt.legend()
plt.show()
# Save the results for testing data as per LSTM
plt.savefig("Actual Vs Predict_TP_LSTM.png")  # Customize filename

# %%
# Print MSE for both training and testing
print(f'MSE on Training Data: {mse_train:.3f}')
print(f'MSE on Testing Data: {mse_test:.3f}')
# Out:
# MSE on Training Data: 0.114
# MSE on Testing Data: 0.454

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Calculate MSE for the validation (test) data
mse_test = mean_squared_error(y_test_actual, y_test_inv)

# Calculate RMSE (Root Mean Squared Error) for the validation (test) data
rmse_test = np.sqrt(mse_test)

# Calculate MSE for the validation (test) data
mse_train = mean_squared_error(y_train_actual, y_train_inv)

# Calculate RMSE (Root Mean Squared Error) for the validation (test) data
rmse_train = np.sqrt(mse_train)

print(f'MSE on Testing Data: {mse_test:.3f}')
print(f'RMSE on Testing Data: {rmse_test:.3f}')
print(f'MSE on Training Data: {mse_train:.3f}')
print(f'RMSE on Training Data: {rmse_train:.3f}')
# Out:
# MSE on Testing Data: 0.625
# RMSE on Testing Data: 0.791
# MSE on Training Data: 0.171
# RMSE on Training Data: 0.413
